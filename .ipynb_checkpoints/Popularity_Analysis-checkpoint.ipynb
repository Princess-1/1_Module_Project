# %% [markdown]
# # Popularity - Question 1
# In this Jupyter Notebook we will be using the data provided to determine what movies Microsoft should produced based on Popularity
#
# ## Objectives
# - Determine what genre(s) Microsoft should invest in based on Popularity
#     * What genre has the most ratings
# - Find out how the time of year affects the popularity of movies
# - Which producing studios have the most ratings

# %% [markdown]
# ## Data Cleaning and EDA

# %%
# Import libraries
import sqlite3

import pandas as pd
import numpy as np

import seaborn as sns

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Connect to database and create cursor
conn = sqlite3.connect('movies_db.sqlite')
cur = conn.cursor()

# %%
# Print out table names
cur.execute('''SELECT name
               FROM sqlite_master
               WHERE type='table';
               ''').fetchall()
# Out:
# [('tmdb_movies',),
#  ('tn_movie_budgets',),
#  ('imdb_name_basics',),
#  ('title_akas',),
#  ('bom_movie_gross',),
#  ('imdb_title_basics',),
#  ('title_ratings',),
#  ('rt_reviews',),
#  ('rt_movie_info',)]

# %% [markdown]
# ### tmdb_movies_df - Data Cleaning and EDA

# %%
# I'm choosing to convert all my tables to Dataframes because I feel it will be easier to work with
tmdb_movies_df = pd.read_sql('''SELECT *
                                FROM tmdb_movies''', conn)
tmdb_movies_df.head()
# Out:
#    index            genre_ids     id original_language  \
# 0      0      [12, 14, 10751]  12444                en
# 1      1  [14, 12, 16, 10751]  10191                en
# 2      2        [12, 28, 878]  10138                en
# 3      3      [16, 35, 10751]    862                en
# 4      4        [28, 878, 12]  27205                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                      How to Train Your Dragon      28.734   2010-03-26
# 2                                    Iron Man 2      28.515   2010-05-07
# 3                                     Toy Story      28.005   1995-11-22
# 4                                     Inception      27.920   2010-07-16
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                      How to Train Your Dragon           7.7        7610
# 2                                    Iron Man 2           6.8       12368
# 3                                     Toy Story           7.9       10174
# 4                                     Inception           8.3       22186

# %%
# Set 'Index' as the datasets index
tmdb_movies_df.set_index('index', inplace=True)
tmdb_movies_df.head()
# Out:
#                  genre_ids     id original_language  \
# index
# 0          [12, 14, 10751]  12444                en
# 1      [14, 12, 16, 10751]  10191                en
# 2            [12, 28, 878]  10138                en
# 3          [16, 35, 10751]    862                en
# 4            [28, 878, 12]  27205                en
#
#                                      original_title  popularity release_date  \
# index
# 0      Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                          How to Train Your Dragon      28.734   2010-03-26
# 2                                        Iron Man 2      28.515   2010-05-07
# 3                                         Toy Story      28.005   1995-11-22
# 4                                         Inception      27.920   2010-07-16
#
#                                               title  vote_average  vote_count
# index
# 0      Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                          How to Train Your Dragon           7.7        7610
# 2                                        Iron Man 2           6.8       12368
# 3                                         Toy Story           7.9       10174
# 4                                         Inception           8.3       22186

# %%
# Check df shape to see how many rows and columns we have
print(tmdb_movies_df.shape)

# View info for each column
tmdb_movies_df.info()
# Out:
# (26517, 9)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26517 entries, 0 to 26516
# Data columns (total 9 columns):
# genre_ids            26517 non-null object
# id                   26517 non-null int64
# original_language    26517 non-null object
# original_title       26517 non-null object
# popularity           26517 non-null float64
# release_date         26517 non-null object
# title                26517 non-null object
# vote_average         26517 non-null float64
# vote_count           26517 non-null int64
# dtypes: float64(2), int64(2), object(5)
# memory usage: 2.0+ MB

# %%
# Check for null values if any
print(tmdb_movies_df.isnull().sum())
# Out:
# genre_ids            0
# id                   0
# original_language    0
# original_title       0
# popularity           0
# release_date         0
# title                0
# vote_average         0
# vote_count           0
# dtype: int64

# %%
# It appears we don't have any null value -not any we can see right now at least-
# We'll explore the dataset further by checking out the Unique values
print('Number of Unique values:\n', tmdb_movies_df.nunique())
# Out:
# Number of Unique values:
#  genre_ids             2477
# id                   25497
# original_language       76
# original_title       24835
# popularity            7425
# release_date          3433
# title                24688
# vote_average            91
# vote_count            1693
# dtype: int64

# %%
# Going off the original_title and title columns its safe to assume there are some duplicate
tmdb_movies_df[tmdb_movies_df.duplicated(keep=False)].sort_values(by='title')
# Out:
#                 genre_ids      id original_language  \
# index
# 9191                 [99]   95383                en
# 6315                 [99]   95383                en
# 20070     [99, 36, 10770]  430364                en
# 26340     [99, 36, 10770]  430364                en
# 18016         [18, 10749]  416691                en
# ...                   ...     ...               ...
# 21273                [18]  326382                es
# 15061         [10751, 16]   94196                fr
# 5888          [10751, 16]   94196                fr
# 25188  [10752, 10751, 36]  472553                en
# 21676  [10752, 10751, 36]  472553                en
#
#                                        original_title  popularity  \
# index
# 9191                                       $ellebrity       1.420
# 6315                                       $ellebrity       1.420
# 20070  '85: The Greatest Team in Pro Football History       0.600
# 26340  '85: The Greatest Team in Pro Football History       0.600
# 18016                                         1 Night       5.409
# ...                                               ...         ...
# 21273                                            Zama       5.671
# 15061                                          Zarafa       2.705
# 5888                                           Zarafa       2.705
# 25188                                             Zoo       2.550
# 21676                                             Zoo       2.550
#
#       release_date                                           title  \
# index
# 9191    2013-01-11                                      $ellebrity
# 6315    2013-01-11                                      $ellebrity
# 20070   2018-01-29  '85: The Greatest Team in Pro Football History
# 26340   2018-01-29  '85: The Greatest Team in Pro Football History
# 18016   2017-02-10                                         1 Night
# ...            ...                                             ...
# 21273   2017-09-30                                            Zama
# 15061   2012-11-11                                          Zarafa
# 5888    2012-11-11                                          Zarafa
# 25188   2018-06-08                                             Zoo
# 21676   2018-06-08                                             Zoo
#
#        vote_average  vote_count
# index
# 9191            5.6          12
# 6315            5.6          12
# 20070           7.5           2
# 26340           7.5           2
# 18016           6.4         107
# ...             ...         ...
# 21273           6.9          50
# 15061           6.8          39
# 5888            6.8          39
# 25188           6.6          17
# 21676           6.6          17
#
# [2016 rows x 9 columns]

# %%
# We'll delete the duplicates as part of our data cleaning process
tmdb_movies_df.drop_duplicates(subset=['title'], inplace=True)

# %%
# Check to make sure changes were made to the dataset
tmdb_movies_df[tmdb_movies_df.duplicated(keep=False)].sort_values(by='title')
# Out:
# Empty DataFrame
# Columns: [genre_ids, id, original_language, original_title, popularity, release_date, title, vote_average, vote_count]
# Index: []

# %%
# Going back to the columns datatype we can see that release_date is stored as an object
print(tmdb_movies_df.dtypes)

# That can be fixed by changing it to a datetime dtype
# We can clearly see the before and after below
tmdb_movies_df['release_date'] = pd.to_datetime(tmdb_movies_df['release_date'])
tmdb_movies_df.info()
# Out:
# genre_ids             object
# id                     int64
# original_language     object
# original_title        object
# popularity           float64
# release_date          object
# title                 object
# vote_average         float64
# vote_count             int64
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24688 entries, 0 to 26516
# Data columns (total 9 columns):
# genre_ids            24688 non-null object
# id                   24688 non-null int64
# original_language    24688 non-null object
# original_title       24688 non-null object
# popularity           24688 non-null float64
# release_date         24688 non-null datetime64[ns]
# title                24688 non-null object
# vote_average         24688 non-null float64
# vote_count           24688 non-null int64
# dtypes: datetime64[ns](1), float64(2), int64(2), object(4)
# memory usage: 1.9+ MB

# %% [markdown]
# ### What the most popular month(s) to release a movie?

# %%
tmdb_movies_df['release_month'] = tmdb_movies_df['release_date'].dt.strftime('%B')
tmdb_movies_df.head()
# Out:
#                  genre_ids     id original_language  \
# index
# 0          [12, 14, 10751]  12444                en
# 1      [14, 12, 16, 10751]  10191                en
# 2            [12, 28, 878]  10138                en
# 3          [16, 35, 10751]    862                en
# 4            [28, 878, 12]  27205                en
#
#                                      original_title  popularity release_date  \
# index
# 0      Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                          How to Train Your Dragon      28.734   2010-03-26
# 2                                        Iron Man 2      28.515   2010-05-07
# 3                                         Toy Story      28.005   1995-11-22
# 4                                         Inception      27.920   2010-07-16
#
#                                               title  vote_average  vote_count  \
# index
# 0      Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                          How to Train Your Dragon           7.7        7610
# 2                                        Iron Man 2           6.8       12368
# 3                                         Toy Story           7.9       10174
# 4                                         Inception           8.3       22186
#
#       release_month
# index
# 0          November
# 1             March
# 2               May
# 3          November
# 4              July

# %%
# Visualize the popularity of movies based on month released
plt.figure(figsize=(12, 7))
sns.barplot(x='release_month', y='popularity', data=tmdb_movies_df)
plt.show()

# %% [markdown]
# July, August, and December look like the highest points on the graph. Based on the graph I would not conclude that the month released had a huge impact on the popularity of the movie.

# %% [markdown]
# ### What's the most popular day for movie releases?

# %%
from datetime import datetime
tmdb_movies_df['release_day'] = tmdb_movies_df['release_date'].dt.strftime('%A')
tmdb_movies_df.head()
# Out:
#                  genre_ids     id original_language  \
# index
# 0          [12, 14, 10751]  12444                en
# 1      [14, 12, 16, 10751]  10191                en
# 2            [12, 28, 878]  10138                en
# 3          [16, 35, 10751]    862                en
# 4            [28, 878, 12]  27205                en
#
#                                      original_title  popularity release_date  \
# index
# 0      Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                          How to Train Your Dragon      28.734   2010-03-26
# 2                                        Iron Man 2      28.515   2010-05-07
# 3                                         Toy Story      28.005   1995-11-22
# 4                                         Inception      27.920   2010-07-16
#
#                                               title  vote_average  vote_count  \
# index
# 0      Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                          How to Train Your Dragon           7.7        7610
# 2                                        Iron Man 2           6.8       12368
# 3                                         Toy Story           7.9       10174
# 4                                         Inception           8.3       22186
#
#       release_month release_day
# index
# 0          November      Friday
# 1             March      Friday
# 2               May      Friday
# 3          November   Wednesday
# 4              July      Friday

# %%
# Visualize the popularity of movies based on month released
plt.figure(figsize=(12, 7))
sns.barplot(x='release_day', y='popularity', data=tmdb_movies_df)
plt.xlabel('Day of Week', fontsize= 15)
plt.ylabel('Popularity', fontsize=15)
plt.title('Best day(s) for movie release')
plt.show()

# %% [markdown]
# Looking at the graph it is very clear that movies released on Friday's are the most popular.

# %%
title_df = pd.read_sql('''SELECT *
                                FROM imdb_title_basics''', conn)
title_df.head()
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 3        2018              NaN          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy

# %%
title_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 6 columns):
# tconst             146144 non-null object
# primary_title      146144 non-null object
# original_title     146123 non-null object
# start_year         146144 non-null int64
# runtime_minutes    114405 non-null float64
# genres             140736 non-null object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 6.7+ MB

# %%
title_df.isna().sum()
# Out:
# tconst                 0
# primary_title          0
# original_title        21
# start_year             0
# runtime_minutes    31739
# genres              5408
# dtype: int64

# %%
title_df.dropna(inplace=True)

# %%
title_df.isna().sum().any()
# Out:
# False

# %%
print('Number of Unique values:\n', title_df.nunique())
# Out:
# Number of Unique values:
#  tconst             112232
# primary_title      105478
# original_title     106905
# start_year             13
# runtime_minutes       361
# genres               1040
# dtype: int64

# %%
title_df.head()
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
# 5  tt0111414                      A Thin Life                 A Thin Life
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 4        2017             80.0  Comedy,Drama,Fantasy
# 5        2018             75.0                Comedy

# %%
title_df[title_df.duplicated(keep=False)].sort_values(by='original_title')
# Out:
# Empty DataFrame
# Columns: [tconst, primary_title, original_title, start_year, runtime_minutes, genres]
# Index: []

# %%
title_ratings_df = pd.read_sql('''SELECT *
                                FROM title_ratings''', conn)
title_ratings_df.head()
# Out:
#        tconst  averagerating  numvotes
# 0  tt10356526            8.3        31
# 1  tt10384606            8.9       559
# 2   tt1042974            6.4        20
# 3   tt1043726            4.2     50352
# 4   tt1060240            6.5        21

# %%
title_ratings_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73856 entries, 0 to 73855
# Data columns (total 3 columns):
# tconst           73856 non-null object
# averagerating    73856 non-null float64
# numvotes         73856 non-null int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.7+ MB

# %%
title_ratings_df.isna().sum()
# Out:
# tconst           0
# averagerating    0
# numvotes         0
# dtype: int64

# %%
title_ratings_df[title_ratings_df.duplicated(keep=False)].sort_values(by='tconst')
# Out:
# Empty DataFrame
# Columns: [tconst, averagerating, numvotes]
# Index: []

# %%
new_title_df = pd.merge(title_df, title_ratings_df, on='tconst')
new_title_df.head()
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0100275         The Wandering Soap Opera       La Telenovela Errante
# 4  tt0137204                  Joe Finds Grace             Joe Finds Grace
#
#    start_year  runtime_minutes                      genres  averagerating  \
# 0        2013            175.0          Action,Crime,Drama            7.0
# 1        2019            114.0             Biography,Drama            7.2
# 2        2018            122.0                       Drama            6.9
# 3        2017             80.0        Comedy,Drama,Fantasy            6.5
# 4        2017             83.0  Adventure,Animation,Comedy            8.1
#
#    numvotes
# 0        77
# 1        43
# 2      4517
# 3       119
# 4       263

# %%
new_title_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 65720 entries, 0 to 65719
# Data columns (total 8 columns):
# tconst             65720 non-null object
# primary_title      65720 non-null object
# original_title     65720 non-null object
# start_year         65720 non-null int64
# runtime_minutes    65720 non-null float64
# genres             65720 non-null object
# averagerating      65720 non-null float64
# numvotes           65720 non-null int64
# dtypes: float64(2), int64(2), object(4)
# memory usage: 4.5+ MB

# %%
print(new_title_df['genres'][:1])
# Out:
# 0    Action,Crime,Drama
# Name: genres, dtype: object

# %%
df = pd.merge(tmdb_movies_df, title_df, on='original_title')
df.head()
# Out:
#              genre_ids     id original_language  \
# 0      [12, 14, 10751]  12444                en
# 1  [14, 12, 16, 10751]  10191                en
# 2        [12, 28, 878]  10138                en
# 3        [28, 878, 12]  27205                en
# 4      [12, 14, 10751]  32657                en
#
#                                       original_title  popularity release_date  \
# 0       Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                           How to Train Your Dragon      28.734   2010-03-26
# 2                                         Iron Man 2      28.515   2010-05-07
# 3                                          Inception      27.920   2010-07-16
# 4  Percy Jackson & the Olympians: The Lightning T...      26.691   2010-02-11
#
#                                                title  vote_average  \
# 0       Harry Potter and the Deathly Hallows: Part 1           7.7
# 1                           How to Train Your Dragon           7.7
# 2                                         Iron Man 2           6.8
# 3                                          Inception           8.3
# 4  Percy Jackson & the Olympians: The Lightning T...           6.1
#
#    vote_count release_month release_day     tconst  \
# 0       10788      November      Friday  tt0926084
# 1        7610         March      Friday  tt0892769
# 2       12368           May      Friday  tt1228705
# 3       22186          July      Friday  tt1375666
# 4        4229      February    Thursday  tt0814255
#
#                                        primary_title  start_year  \
# 0       Harry Potter and the Deathly Hallows: Part 1        2010
# 1                           How to Train Your Dragon        2010
# 2                                         Iron Man 2        2010
# 3                                          Inception        2010
# 4  Percy Jackson & the Olympians: The Lightning T...        2010
#
#    runtime_minutes                      genres
# 0            146.0   Adventure,Fantasy,Mystery
# 1             98.0  Action,Adventure,Animation
# 2            124.0     Action,Adventure,Sci-Fi
# 3            148.0     Action,Adventure,Sci-Fi
# 4            118.0    Adventure,Family,Fantasy

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16375 entries, 0 to 16374
# Data columns (total 16 columns):
# genre_ids            16375 non-null object
# id                   16375 non-null int64
# original_language    16375 non-null object
# original_title       16375 non-null object
# popularity           16375 non-null float64
# release_date         16375 non-null datetime64[ns]
# title                16375 non-null object
# vote_average         16375 non-null float64
# vote_count           16375 non-null int64
# release_month        16375 non-null object
# release_day          16375 non-null object
# tconst               16375 non-null object
# primary_title        16375 non-null object
# start_year           16375 non-null int64
# runtime_minutes      16375 non-null float64
# genres               16375 non-null object
# dtypes: datetime64[ns](1), float64(3), int64(3), object(9)
# memory usage: 2.1+ MB
