# %% [markdown]
# # Data Cleaning and EDA
# ## Objectives
# In this Jupyter Notebook we will be focusing on:
# - Taking a look at each table
# - Dealing with Null values and missing data
# - EDA to get more insight on the data

# %% [markdown]
# ## Import Libraries

# %%
# Import all necessary libraries
import sqlite3

import pandas as pd
import numpy as np

import seaborn as sns

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Connect to Database

# %%
# Connect to database and create cursor
conn = sqlite3.connect('movies_db.sqlite')
cur = conn.cursor()

# %%
# Print out table names
cur.execute('''SELECT name
               FROM sqlite_master
               WHERE type='table';
               ''').fetchall()
# Out:
# [('tmdb_movies',),
#  ('tn_movie_budgets',),
#  ('imdb_name_basics',),
#  ('title_akas',),
#  ('bom_movie_gross',),
#  ('imdb_title_basics',),
#  ('title_ratings',),
#  ('rt_reviews',),
#  ('rt_movie_info',)]

# %%
# One off example to ensure the data loads correctly
conn.execute('''SELECT *
                FROM title_akas''').fetchall()
# Out:
# [('tt0369610', 10, 'Джурасик свят', 'BG', 'bg', None, None, 0.0),
#  ('tt0369610', 11, 'Jurashikku warudo', 'JP', None, 'imdbDisplay', None, 0.0),
#  ('tt0369610',
#   12,
#   'Jurassic World: O Mundo dos Dinossauros',
#   'BR',
#   None,
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt0369610',
#   13,
#   'O Mundo dos Dinossauros',
#   'BR',
#   None,
#   None,
#   'short title',
#   0.0),
#  ('tt0369610', 14, 'Jurassic World', 'FR', None, 'imdbDisplay', None, 0.0),
#  ('tt0369610', 15, 'Jurassic World', 'GR', None, 'imdbDisplay', None, 0.0),
#  ('tt0369610', 16, 'Jurassic World', 'IT', None, 'imdbDisplay', None, 0.0),
#  ('tt0369610', 17, 'Jurski svijet', 'HR', None, 'imdbDisplay', None, 0.0),
#  ('tt0369610', 18, "Olam ha'Yura", 'IL', 'he', 'imdbDisplay', None, 0.0),
#  ('tt0369610',
#   19,
#   'Jurassic World: Mundo Jurásico',
#   'MX',
#   None,
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt0369610',
#   1,
#   'Jurassic World: Sauruste maailm',
#   'EE',
#   None,
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt0369610', 20, 'Jurassic World', 'SE', None, 'imdbDisplay', None, 0.0),
#  ('tt0369610', 21, 'Jurassic World 3D', 'US', None, None, '3-D version', 0.0),
#  ('tt0369610', 22, 'Jurassic World 3D', 'DE', None, None, '3-D version', 0.0),
#  ('tt0369610', 23, 'Jurassic World 3D', 'XWW', None, None, '3-D version', 0.0),
#  ('tt0369610',
#   24,
#   'Juras laikmeta pasaule',
#   'LV',
#   None,
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt0369610', 25, 'Mundo Jurássico', 'PT', None, 'imdbDisplay', None, 0.0),
#  ('tt0369610', 26, 'Мир Юрского периода', 'RU', None, None, None, 0.0),
#  ('tt0369610', 27, 'Jurský svět', 'CZ', None, None, None, 0.0),
#  ('tt0369610', 28, 'Monde jurassique', 'CA', 'fr', 'imdbDisplay', None, 0.0),
#  ('tt0369610', 29, 'Jurassic World', 'US', None, None, None, 0.0),
#  ('tt0369610', 2, 'Ebb Tide', 'US', None, None, 'fake working title', 0.0),
#  ('tt0369610',
#   30,
#   'Jurassic World: Mundo Jurásico',
#   'CL',
#   None,
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt0369610', 31, 'Jurassic World', 'RO', None, 'imdbDisplay', None, 0.0),
#  ('tt0369610',
#   32,
#   'Juros periodo pasaulis',
#   'LT',
#   None,
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt0369610', 33, 'Jurassic World', 'FI', None, 'imdbDisplay', None, 0.0),
#  ('tt0369610',
#   34,
#   'Jurassic World: Mundo jurásico',
#   'PE',
#   None,
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt0369610',
#   35,
#   'Jurassic Park 4',
#   'TR',
#   'tr',
#   None,
#   'informal alternative title',
#   0.0),
#  ('tt0369610', 36, 'Jurassic Park IV', 'US', None, 'working', None, 0.0),
#  ('tt0369610', 37, 'Jurassic World', 'NO', None, 'imdbDisplay', None, 0.0),
#  ('tt0369610', 38, 'Jurski svet', 'SI', None, 'imdbDisplay', None, 0.0),
#  ('tt0369610', 39, 'Свiт Юрського перiоду', 'UA', None, None, None, 0.0),
#  ('tt0369610', 3, 'The Gioi Khung Long', 'VN', None, 'imdbDisplay', None, 0.0),
#  ('tt0369610', 40, 'Jurassic World', 'DK', None, 'imdbDisplay', None, 0.0),
#  ('tt0369610', 41, 'Svet iz doba jure', 'RS', None, 'imdbDisplay', None, 0.0),
#  ('tt0369610', 42, 'Jurský svet', 'SK', None, None, None, 0.0),
#  ('tt0369610', 43, 'Jurassic World', 'TR', 'tr', 'imdbDisplay', None, 0.0),
#  ('tt0369610',
#   44,
#   'Jurassic Park 4',
#   'US',
#   None,
#   None,
#   'informal alternative title',
#   0.0),
#  ('tt0369610', 45, 'Jurassic World', None, None, 'original', None, 1.0),
#  ('tt0369610', 46, 'Jurassic World', 'ES', None, 'imdbDisplay', None, 0.0),
#  ('tt0369610', 47, 'Jurassic World', 'HU', None, 'imdbDisplay', None, 0.0),
#  ('tt0369610', 48, 'Park jurajski 4', 'PL', None, 'alternative', None, 0.0),
#  ('tt0369610', 4, 'Yur dövrü Dünyasi', 'AZ', None, 'imdbDisplay', None, 0.0),
#  ('tt0369610',
#   5,
#   'Iuruli periodis samyaro',
#   'GE',
#   'ka',
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt0369610', 6, 'Jurassic World', 'PL', None, 'imdbDisplay', None, 0.0),
#  ('tt0369610', 7, 'Mundo Jurásico', 'UY', None, None, '3-D version', 0.0),
#  ('tt0369610', 8, 'Jurassic World 3D', 'PL', None, None, '3-D version', 0.0),
#  ('tt0369610',
#   9,
#   'Jurassic World - Mundo Jurásico',
#   'AR',
#   None,
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt0381957', 1, 'Cloud Cuckoo Land', 'GB', None, None, None, 0.0),
#  ('tt0401729',
#   10,
#   'Джон Картер: Мiж двох свiтiв',
#   'UA',
#   None,
#   None,
#   None,
#   0.0),
#  ('tt0401729', 11, 'John Carter of Mars', 'US', None, 'working', None, 0.0),
#  ('tt0401729', 12, 'A Princess of Mars', 'US', None, 'working', None, 0.0),
#  ('tt0401729',
#   13,
#   'John Carter - Entre dos mundos',
#   'AR',
#   None,
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt0401729',
#   14,
#   'John Carter Maaveeran',
#   'IN',
#   'ta',
#   None,
#   'dubbed version',
#   0.0),
#  ('tt0401729', 15, 'Džonas Karteris', 'LT', None, None, None, 0.0),
#  ('tt0401729', 16, 'John Carter', 'PT', None, 'imdbDisplay', None, 0.0),
#  ('tt0401729',
#   17,
#   'John Carter: Mezi dvěma světy',
#   'CZ',
#   None,
#   None,
#   None,
#   0.0),
#  ('tt0401729',
#   18,
#   'John Carter: Ανάμεσα σε δύο κόσμους',
#   'GR',
#   None,
#   None,
#   None,
#   0.0),
#  ('tt0401729',
#   19,
#   'John Carter: Medzi dvoma svetmi',
#   'SK',
#   None,
#   None,
#   None,
#   0.0),
#  ('tt0401729',
#   1,
#   'John Carter: Zwischen zwei Welten',
#   'DE',
#   None,
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt0401729', 20, 'Джон Картер', 'RU', None, None, None, 0.0),
#  ('tt0401729', 21, 'John Carter', 'FR', None, 'imdbDisplay', None, 0.0),
#  ('tt0401729',
#   22,
#   'John Carter - Anamesa se dyo kosmous',
#   'GR',
#   None,
#   None,
#   'transliterated ISO-LATIN-1 title',
#   0.0),
#  ('tt0401729',
#   23,
#   'Джон Картър: Между два свята',
#   'BG',
#   'bg',
#   None,
#   None,
#   0.0),
#  ('tt0401729',
#   24,
#   'John Carter Mahaveerudu',
#   'IN',
#   'te',
#   None,
#   'dubbed version',
#   0.0),
#  ('tt0401729',
#   25,
#   'John Carter: Entre dos mundos',
#   'PE',
#   None,
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt0401729', 26, 'John Carter', 'HR', None, 'imdbDisplay', None, 0.0),
#  ('tt0401729',
#   27,
#   'John Carter: Entre Dois Mundos',
#   'BR',
#   None,
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt0401729', 28, 'John Carter', 'CL', None, 'imdbDisplay', None, 0.0),
#  ('tt0401729', 29, 'John Carter', 'ES', None, 'imdbDisplay', None, 0.0),
#  ('tt0401729', 2, 'John Carter', 'US', None, None, None, 0.0),
#  ('tt0401729', 30, 'John Carter', 'HU', None, 'imdbDisplay', None, 0.0),
#  ('tt0401729',
#   31,
#   'John Carter: Iki Dünya Arasinda',
#   'TR',
#   'tr',
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt0401729', 32, 'John Carter', 'IL', 'he', 'imdbDisplay', None, 0.0),
#  ('tt0401729', 33, 'John Carter', 'PL', None, 'imdbDisplay', None, 0.0),
#  ('tt0401729',
#   34,
#   'John Carter: Entre dos mundos',
#   'UY',
#   None,
#   None,
#   '3-D version',
#   0.0),
#  ('tt0401729', 3, 'John Carter', 'RO', None, 'imdbDisplay', None, 0.0),
#  ('tt0401729', 4, 'John Carter', 'CA', 'fr', 'imdbDisplay', None, 0.0),
#  ('tt0401729', 5, 'Barsoom', 'US', None, None, 'fake working title', 0.0),
#  ('tt0401729',
#   6,
#   'Džon Karter - Između dva sveta',
#   'RS',
#   None,
#   None,
#   None,
#   0.0),
#  ('tt0401729', 7, 'John Carter', None, None, 'original', None, 1.0),
#  ('tt0401729', 8, 'John Carter', 'CO', None, 'imdbDisplay', None, 0.0),
#  ('tt0401729',
#   9,
#   'John Carter: Entre dos mundos',
#   'MX',
#   None,
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt10010134',
#   1,
#   "Versailles Rediscovered - The Sun King's Vanished Palace",
#   None,
#   None,
#   'original',
#   None,
#   1.0),
#  ('tt10010134',
#   2,
#   'Versailles: Le Palais retrouvé du Roi Soleil',
#   'FR',
#   None,
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt10010134',
#   3,
#   'Versailles: Palast des Sonnenkönigs',
#   'DE',
#   None,
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt10027708',
#   1,
#   'Miguelito - Canto a Borinquen',
#   None,
#   None,
#   'original',
#   None,
#   1.0),
#  ('tt10027708', 2, 'Miguelito', 'XWW', 'en', 'imdbDisplay', None, 0.0),
#  ('tt10027708',
#   3,
#   'Miguelito - Canto a Borinquen',
#   'AU',
#   None,
#   None,
#   None,
#   0.0),
#  ('tt10027708', 4, 'Miguelito', 'AU', 'en', None, None, 0.0),
#  ('tt10050722', 1, "Thing I Don't Get", None, None, 'original', None, 1.0),
#  ('tt10050722',
#   2,
#   'Fünf Dinge, die ich nicht verstehe',
#   'DE',
#   None,
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt10084780', 1, 'Vinara sodara veera kumara', 'IN', None, None, None, 0.0),
#  ('tt10121294',
#   1,
#   'This Jelly Doughnut Feeling',
#   None,
#   None,
#   'original',
#   None,
#   1.0),
#  ('tt10121294',
#   2,
#   'This Jelly Doughnut Feeling Ich fühl mich Berliner',
#   'DE',
#   None,
#   None,
#   'original script title',
#   0.0),
#  ('tt1014759',
#   10,
#   'Alice Dar Sarzamin E Ajayeb',
#   'IE',
#   'en',
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt1014759',
#   11,
#   'Η Αλίκη στη χώρα των θαυμάτων',
#   'GR',
#   None,
#   None,
#   None,
#   0.0),
#  ('tt1014759',
#   12,
#   'Alicia en el país de las maravillas',
#   'UY',
#   None,
#   None,
#   None,
#   0.0),
#  ('tt1014759',
#   13,
#   'Alice în Tara Minunilor',
#   'RO',
#   None,
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt1014759',
#   14,
#   'Alice no País das Maravilhas',
#   'PT',
#   None,
#   None,
#   None,
#   0.0),
#  ('tt1014759', 15, 'Алиса в Стране чудес', 'RU', None, None, None, 0.0),
#  ('tt1014759', 16, "Aliza Be Eretz Ha Pla'ot", 'IL', 'he', None, None, 0.0),
#  ('tt1014759', 17, 'Alis harikalar diyarinda', 'TR', 'tr', None, None, 0.0),
#  ('tt1014759',
#   18,
#   'Alice Csodaországban',
#   'HU',
#   None,
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt1014759', 19, 'Alisa stebuklu salyje', 'LT', None, None, None, 0.0),
#  ('tt1014759', 1, 'Alice i Underlandet', 'FI', 'sv', 'imdbDisplay', None, 0.0),
#  ('tt1014759', 20, 'Alice im Wunderland', 'DE', None, None, None, 0.0),
#  ('tt1014759',
#   21,
#   'Alisa saotsrebata kvekanashi',
#   'GE',
#   None,
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt1014759',
#   22,
#   'Alice i Eventyrland',
#   'NO',
#   None,
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt1014759',
#   23,
#   'Alice in Wonderland: An IMAX 3D Experience',
#   'US',
#   None,
#   None,
#   'IMAX version',
#   0.0),
#  ('tt1014759', 24, 'Alice im Wunderland', 'AT', None, None, None, 0.0),
#  ('tt1014759',
#   25,
#   'Alicia en el país de las maravillas',
#   'AR',
#   None,
#   None,
#   None,
#   0.0),
#  ('tt1014759',
#   26,
#   'Алиса в страната на чудесата',
#   'BG',
#   'bg',
#   None,
#   None,
#   0.0),
#  ('tt1014759',
#   27,
#   'Alicia en el país de las maravillas',
#   'PE',
#   None,
#   None,
#   None,
#   0.0),
#  ('tt1014759',
#   28,
#   'Alice i Underlandet',
#   'SE',
#   None,
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt1014759',
#   29,
#   'Alicia en el País de las Maravillas',
#   'ES',
#   None,
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt1014759',
#   2,
#   'Alice Csodaországban IMAX 3D',
#   'HU',
#   None,
#   None,
#   'IMAX version',
#   0.0),
#  ('tt1014759',
#   30,
#   'Alicia en el país de las maravillas',
#   'MX',
#   None,
#   None,
#   None,
#   0.0),
#  ('tt1014759',
#   31,
#   'I Aliki sti hora ton thavmaton',
#   'GR',
#   None,
#   None,
#   'transliterated ISO-LATIN-1 title',
#   0.0),
#  ('tt1014759',
#   32,
#   'Alica v cudezni dezeli',
#   'SI',
#   None,
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt1014759', 33, 'Alisa u zemlji čudesa', 'HR', None, None, None, 0.0),
#  ('tt1014759', 34, 'Alisa u zemlji čuda', 'RS', None, None, None, 0.0),
#  ('tt1014759',
#   35,
#   'Alice i eventyrland',
#   'NO',
#   None,
#   None,
#   'dubbed version',
#   0.0),
#  ('tt1014759',
#   36,
#   'Alice au pays des merveilles',
#   'CA',
#   'fr',
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt1014759', 37, 'Alice in Wonderland', 'US', None, None, None, 0.0),
#  ('tt1014759', 38, 'Liisa Ihmemaassa', 'FI', None, 'imdbDisplay', None, 0.0),
#  ('tt1014759',
#   39,
#   'Alica v krajine zázrakov',
#   'SK',
#   None,
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt1014759', 3, 'Alice in Wonderland', 'JP', 'en', None, None, 0.0),
#  ('tt1014759', 40, 'Alice in Wonderland', None, None, 'original', None, 1.0),
#  ('tt1014759', 41, 'Alice imedemaal', 'EE', None, None, None, 0.0),
#  ('tt1014759',
#   42,
#   'Alice au pays des merveilles',
#   'FR',
#   None,
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt1014759', 4, 'Alice no País das Maravilhas', 'BR', None, None, None, 0.0),
#  ('tt1014759', 5, 'Alenka v říši divů', 'CZ', None, None, None, 0.0),
#  ('tt1014759', 6, 'Alice', 'US', None, None, 'original script title', 0.0),
#  ('tt1014759',
#   7,
#   'Alicja w Krainie Czarów',
#   'PL',
#   None,
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt1014759', 8, 'Алiса в краiiнi чудес', 'UA', None, None, None, 0.0),
#  ('tt1014759', 9, 'Alice i Eventyrland', 'DK', None, 'imdbDisplay', None, 0.0),
#  ('tt10214198', 1, 'Gou yan kan ren xin', None, None, 'original', None, 1.0),
#  ('tt10214198', 2, 'Push and Shove', None, None, None, None, 0.0),
#  ('tt10214198', 3, 'Gou yan kan ren xin', 'CN', None, None, None, 0.0),
#  ('tt10225354', 1, 'Volviendo a Casa', 'AR', None, None, None, 0.0),
#  ('tt10225354', 2, 'Volviendo a Casa', None, None, 'original', None, 1.0),
#  ('tt10225354', 3, 'Returning Home', 'XWW', 'en', 'alternative', None, 0.0),
#  ('tt10225420', 1, 'El Universo En Que Te Amé', 'AR', None, None, None, 0.0),
#  ('tt10225420',
#   2,
#   'The Universe in Which I Loved You',
#   'XWW',
#   'en',
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt10225420',
#   3,
#   'El Universo En Que Te Amé',
#   None,
#   None,
#   'original',
#   None,
#   1.0),
#  ('tt10308634', 1, 'My First Client', None, None, 'original', None, 1.0),
#  ('tt10308634', 2, 'My First Client', 'KR', None, None, None, 0.0),
#  ('tt10308634', 3, 'Young Clients', 'XWW', 'en', 'alternative', None, 0.0),
#  ('tt10351180', 1, 'BadBoy', None, None, 'original', None, 1.0),
#  ('tt10351180', 2, 'BadBoy', 'IN', None, None, None, 0.0),
#  ('tt10351180', 3, 'Bad Boy', 'XWW', None, None, 'alternative spelling', 0.0),
#  ('tt10379338', 1, 'Guys Night Out', 'US', None, 'imdbDisplay', None, 0.0),
#  ('tt10379338', 2, 'Guys Night Out', None, None, 'original', None, 1.0),
#  ('tt10379338', 3, 'Random Night Out', 'US', None, None, None, 0.0),
#  ('tt10446418', 1, 'Icon', 'RS', None, None, None, 0.0),
#  ('tt10446418', 2, 'Icon', None, None, 'original', None, 1.0),
#  ('tt10446418', 3, 'The Icon', 'US', None, 'alternative', None, 0.0),
#  ('tt1179034', 10, 'Armastusega Pariisist', 'EE', None, None, None, 0.0),
#  ('tt1179034', 11, 'Dupla Implacável', 'BR', None, None, None, 0.0),
#  ('tt1179034', 12, 'París en la Mira', 'MX', None, None, None, 0.0),
#  ('tt1179034', 13, 'Sangre y amor en París', 'AR', None, None, None, 0.0),
#  ('tt1179034', 14, 'From Paris with Love', 'FR', None, None, None, 0.0),
#  ('tt1179034',
#   15,
#   'Desde París con amor',
#   'ES',
#   None,
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt1179034', 16, 'Из Парижа с любовью', 'RU', None, None, None, 0.0),
#  ('tt1179034', 17, "MiParis be'ahava", 'IL', 'he', None, None, 0.0),
#  ('tt1179034',
#   18,
#   'Linkejimai is Paryziaus',
#   'LT',
#   None,
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt1179034', 19, 'Bez soucitu', 'CZ', None, 'imdbDisplay', None, 0.0),
#  ('tt1179034', 1, 'От Париж с любов', 'BG', 'bg', None, None, 0.0),
#  ('tt1179034', 20, 'De Paris com Amor', 'PT', None, None, None, 0.0),
#  ('tt1179034', 21, 'Από το Παρίσι με αγάπη', 'GR', None, None, None, 0.0),
#  ('tt1179034',
#   22,
#   'From Paris with Love',
#   'IT',
#   None,
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt1179034',
#   23,
#   'Din Paris, cu dragoste',
#   'RO',
#   None,
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt1179034', 24, "Paris'ten sevgilerle", 'TR', 'tr', None, None, 0.0),
#  ('tt1179034',
#   25,
#   'Iz Pariza s ljubavlju',
#   'RS',
#   None,
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt1179034', 26, 'Pozdrowienia z Paryza', 'PL', None, None, None, 0.0),
#  ('tt1179034',
#   27,
#   'Bons baisers de Paris',
#   'CA',
#   'fr',
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt1179034', 28, 'París en la mira', 'PE', None, None, None, 0.0),
#  ('tt1179034',
#   2,
#   'Apo to Parisi me agapi',
#   'GR',
#   None,
#   None,
#   'transliterated ISO-LATIN-1 title',
#   0.0),
#  ('tt1179034',
#   3,
#   'Iz Pariza z ljubeznijo',
#   'SI',
#   None,
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt1179034', 4, "З Парижу з любов'ю", 'UA', None, None, None, 0.0),
#  ('tt1179034', 5, 'From Paris with Love', None, None, 'original', None, 1.0),
#  ('tt1179034',
#   6,
#   'Párizsból szeretettel',
#   'HU',
#   None,
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt1179034',
#   7,
#   'Sangre y amor en París',
#   'CL',
#   None,
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt1179034',
#   8,
#   'From Paris with Love',
#   'DK',
#   None,
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt1179034',
#   9,
#   'Iz Pariza s ljubavlju',
#   'HR',
#   None,
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt1180174', 1, 'Liberty', 'US', None, None, None, 0.0),
#  ('tt1182315', 1, 'Negro Buenos Aires', None, None, 'original', None, 1.0),
#  ('tt1182315', 2, 'Black Buenos Aires', 'XWW', 'en', 'imdbDisplay', None, 0.0),
#  ('tt1182315', 3, 'Negro Buenos Aires', 'ES', None, None, None, 0.0),
#  ('tt1182315', 4, 'Dark Buenos Aires', 'US', None, 'imdbDisplay', None, 0.0),
#  ('tt1189904', 1, 'Small Town Hero', 'US', None, None, None, 0.0),
#  ('tt1194173', 10, 'Bornovo nasleđe', 'RS', None, None, None, 0.0),
#  ('tt1194173',
#   11,
#   "Dziedzictwo Bourne'a",
#   'PL',
#   None,
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt1194173', 12, 'O Legado Bourne', 'BR', None, 'imdbDisplay', None, 0.0),
#  ('tt1194173', 13, 'Наследството на Борн', 'BG', 'bg', None, None, 0.0),
#  ('tt1194173',
#   14,
#   "Jason Bourne: L'héritage",
#   'FR',
#   None,
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt1194173', 15, "Bourne'un Mirasi", 'TR', 'tr', 'imdbDisplay', None, 0.0),
#  ('tt1194173', 16, 'Bornas. Palikimas', 'LT', None, 'imdbDisplay', None, 0.0),
#  ('tt1194173', 17, 'Η κληρονομιά του Μπορν', 'GR', None, None, None, 0.0),
#  ('tt1194173', 18, 'Borna mantojums', 'LV', None, 'imdbDisplay', None, 0.0),
#  ('tt1194173',
#   19,
#   'I klironomia tou Bourne',
#   'GR',
#   None,
#   None,
#   'transliterated ISO-LATIN-1 title',
#   0.0),
#  ('tt1194173', 1, 'Эволюция Борна', 'RU', None, None, None, 0.0),
#  ('tt1194173', 20, 'O Legado de Bourne', 'PT', None, 'imdbDisplay', None, 0.0),
#  ('tt1194173', 21, 'El Legado Bourne', 'CO', None, 'imdbDisplay', None, 0.0),
#  ('tt1194173', 22, 'Bourneuv odkaz', 'CZ', None, 'imdbDisplay', None, 0.0),
#  ('tt1194173', 23, 'A Bourne-hagyaték', 'HU', None, 'imdbDisplay', None, 0.0),
#  ('tt1194173',
#   24,
#   'El legado de Bourne',
#   'ES',
#   None,
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt1194173', 25, 'Bourneovo nasljeđe', 'HR', None, None, None, 0.0),
#  ('tt1194173', 26, 'Zehut gnuva', 'IL', 'he', 'imdbDisplay', None, 0.0),
#  ('tt1194173',
#   27,
#   'Das Bourne Vermächtnis',
#   'DE',
#   None,
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt1194173', 28, 'Спадок Борна', 'UA', None, None, None, 0.0),
#  ('tt1194173', 29, 'El legado Bourne', 'PE', None, 'imdbDisplay', None, 0.0),
#  ('tt1194173', 2, 'Marcher', 'US', None, None, 'fake working title', 0.0),
#  ('tt1194173',
#   30,
#   "La peur dans la peau: L'héritage de Bourne",
#   'CA',
#   'fr',
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt1194173', 31, 'El legado Bourne', 'UY', None, 'imdbDisplay', None, 0.0),
#  ('tt1194173', 32, 'The Bourne Legacy', None, None, 'original', None, 1.0),
#  ('tt1194173', 3, 'El Legado Bourne', 'MX', None, 'imdbDisplay', None, 0.0),
#  ('tt1194173', 4, 'El legado Bourne', 'CL', None, 'imdbDisplay', None, 0.0),
#  ('tt1194173',
#   5,
#   'Mostenirea lui Bourne',
#   'RO',
#   None,
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt1194173', 6, 'El legado Bourne', 'AR', None, 'imdbDisplay', None, 0.0),
#  ('tt1194173', 7, "Bourne'i pärand", 'EE', None, 'imdbDisplay', None, 0.0),
#  ('tt1194173', 8, 'Medusan perintö', 'FI', None, 'imdbDisplay', None, 0.0),
#  ('tt1194173', 9, 'The Bourne Legacy', 'US', None, None, None, 0.0),
#  ('tt1210047',
#   1,
#   'Snatched! Curse of the Pink Panties 2',
#   'US',
#   None,
#   'alternative',
#   None,
#   0.0),
#  ('tt1210047', 2, 'Snatched!', None, None, 'original', None, 1.0),
#  ('tt1210047',
#   3,
#   'Curse of the Pink Panties II',
#   'US',
#   None,
#   'working',
#   None,
#   0.0),
#  ('tt1210047', 4, 'Snatched!', 'US', None, None, None, 0.0),
#  ('tt1219289', 10, 'Sin Límites', 'AR', None, 'imdbDisplay', None, 0.0),
#  ('tt1219289', 11, 'Bezgranicno', 'BA', 'hr', 'imdbDisplay', None, 0.0),
#  ('tt1219289', 12, 'Csúcshatás', 'HU', None, 'imdbDisplay', None, 0.0),
#  ('tt1219289', 13, 'Kõrvalnähud', 'EE', None, 'imdbDisplay', None, 0.0),
#  ('tt1219289', 14, 'The Dark Fields', 'US', None, 'working', None, 0.0),
#  ('tt1219289', 15, 'Ohne Limit', 'DE', None, 'imdbDisplay', None, 0.0),
#  ('tt1219289', 16, 'Sin límites', 'PE', None, 'imdbDisplay', None, 0.0),
#  ('tt1219289', 17, 'Všemocný', 'CZ', None, None, None, 0.0),
#  ('tt1219289', 18, 'Απόλυτη ευφυΐα', 'GR', None, None, None, 0.0),
#  ('tt1219289', 19, 'Limitless', None, None, 'original', None, 1.0),
#  ('tt1219289', 1, 'Lelo gvulot', 'IL', 'he', None, None, 0.0),
#  ('tt1219289', 20, 'Областi темряви', 'UA', None, None, None, 0.0),
#  ('tt1219289', 21, 'Области тьмы', 'RU', None, None, None, 0.0),
#  ('tt1219289', 22, 'Sin límites', 'CL', None, 'imdbDisplay', None, 0.0),
#  ('tt1219289', 23, 'Sin límites', 'MX', None, 'imdbDisplay', None, 0.0),
#  ('tt1219289', 24, 'Sin límites', 'UY', None, 'video', None, 0.0),
#  ('tt1219289', 25, 'Savršena formula', 'HR', None, None, None, 0.0),
#  ('tt1219289', 26, 'Šalutinis efektas', 'LT', None, None, None, 0.0),
#  ('tt1219289', 27, 'Odklenjen', 'SI', None, 'imdbDisplay', None, 0.0),
#  ('tt1219289', 28, 'Sans limites', 'CA', 'fr', 'imdbDisplay', None, 0.0),
#  ('tt1219289', 29, 'Високо напрежение', 'BG', 'bg', None, None, 0.0),
#  ('tt1219289', 2, 'Limitless', 'FR', None, 'imdbDisplay', None, 0.0),
#  ('tt1219289', 30, 'Bez ograničenja', 'RS', None, None, None, 0.0),
#  ('tt1219289', 31, 'Sem Limites', 'BR', None, 'imdbDisplay', None, 0.0),
#  ('tt1219289',
#   32,
#   'Apolyti efyia',
#   'GR',
#   None,
#   None,
#   'transliterated ISO-LATIN-1 title',
#   0.0),
#  ('tt1219289', 33, 'Rajaton', 'FI', None, 'imdbDisplay', None, 0.0),
#  ('tt1219289', 3, 'Sin límites', 'CO', None, 'imdbDisplay', None, 0.0),
#  ('tt1219289', 4, 'Sem Limites', 'PT', None, 'imdbDisplay', None, 0.0),
#  ('tt1219289', 5, 'Sin límites', 'ES', None, 'imdbDisplay', None, 0.0),
#  ('tt1219289', 6, 'Jestem Bogiem', 'PL', None, 'imdbDisplay', None, 0.0),
#  ('tt1219289', 7, 'Limit Yok', 'TR', 'tr', 'imdbDisplay', None, 0.0),
#  ('tt1219289', 8, 'Dincolo de limite', 'RO', None, 'imdbDisplay', None, 0.0),
#  ('tt1219289', 9, 'Limitless', 'US', None, None, None, 0.0),
#  ('tt1220221', 1, 'Motherland', 'US', None, None, None, 0.0),
#  ('tt1220221', 2, 'Mère Afrique', 'FR', None, 'dvd', None, 0.0),
#  ('tt1220221', 3, 'Motherland', None, None, 'original', None, 1.0),
#  ('tt1223236',
#   10,
#   'African Cats - Il regno del coraggio',
#   'IT',
#   None,
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt1223236',
#   11,
#   'Африканские кошки: Королевство смелых',
#   'RU',
#   None,
#   None,
#   None,
#   0.0),
#  ('tt1223236', 12, 'Felinos de Africa', 'VE', None, 'imdbDisplay', None, 0.0),
#  ('tt1223236', 13, 'Feline africane', 'RO', None, 'imdbDisplay', None, 0.0),
#  ('tt1223236',
#   14,
#   'Félins: Le royaume du courage',
#   'FR',
#   None,
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt1223236', 15, 'Gatos Africanos', 'PT', None, 'imdbDisplay', None, 0.0),
#  ('tt1223236',
#   16,
#   'Im Reich der Raubkatzen',
#   'DE',
#   None,
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt1223236', 17, 'African Cats', 'US', None, None, None, 0.0),
#  ('tt1223236', 1, 'African Cats', None, None, 'original', None, 1.0),
#  ('tt1223236', 2, 'Afrika Kedileri', 'TR', 'tr', 'imdbDisplay', None, 0.0),
#  ('tt1223236', 3, 'African Cats', 'GR', None, 'dvd', None, 0.0),
#  ('tt1223236', 4, 'Felinos de África', 'AR', None, 'imdbDisplay', None, 0.0),
#  ('tt1223236',
#   5,
#   'Afrikai macskák - A bátorság birodalma',
#   'HU',
#   None,
#   None,
#   None,
#   0.0),
#  ('tt1223236', 6, "Félins d'Afrique", 'CA', 'fr', None, 'dubbed version', 0.0),
#  ('tt1223236', 7, 'Reino dos Felinos', 'BR', None, 'imdbDisplay', None, 0.0),
#  ('tt1223236', 8, 'Felinos de África', 'PE', None, 'imdbDisplay', None, 0.0),
#  ('tt1223236', 9, 'Afrykanskie koty', 'PL', None, 'imdbDisplay', None, 0.0),
#  ('tt1226831', 1, 'Spark Riders', 'US', None, None, None, 0.0),
#  ('tt1227927',
#   1,
#   'Anruf aus der Hölle',
#   'DE',
#   None,
#   None,
#   'DVD box title',
#   0.0),
#  ('tt1227927', 2, 'Caller ID', None, None, 'original', None, 1.0),
#  ('tt1227927', 3, 'Untitled EZ Project', 'US', None, 'working', None, 0.0),
#  ('tt1227927', 4, 'Caller ID: Entity', 'US', None, None, 'new title', 0.0),
#  ('tt1233259',
#   10,
#   'Prince Killian et le trésor des Templiers',
#   'FR',
#   None,
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt1233259',
#   1,
#   'Prince Killian and the Holy Grail',
#   'CA',
#   'en',
#   None,
#   'DVD box title',
#   0.0),
#  ('tt1233259', 2, 'Captain Thunder', 'US', None, 'imdbDisplay', None, 0.0),
#  ('tt1233259', 3, 'Ritter des heiligen Grals', 'DE', None, 'dvd', None, 0.0),
#  ('tt1233259', 4, 'Order of the Grail', 'GB', None, 'dvd', None, 0.0),
#  ('tt1233259',
#   5,
#   'Prince Killian and the Holy Grail',
#   'US',
#   None,
#   None,
#   'DVD box title',
#   0.0),
#  ('tt1233259',
#   6,
#   'El Capitán Trueno y el Santo Grial',
#   None,
#   None,
#   'original',
#   None,
#   1.0),
#  ('tt1233259',
#   7,
#   'Il cavaliere del Santo Graal',
#   'IT',
#   None,
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt1233259',
#   8,
#   'Capitán Trueno y el Santo Grial',
#   'ES',
#   None,
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt1233259', 9, 'Капитан Гром и Святой Грааль', 'RU', None, None, None, 0.0),
#  ('tt1233328', 1, "My Girlfriend's Back", 'US', None, None, None, 0.0),
#  ('tt1235522', 10, 'Ciudad de sombras', 'PE', None, 'imdbDisplay', None, 0.0),
#  ('tt1235522', 11, 'Broken City', 'US', None, None, None, 0.0),
#  ('tt1235522', 12, 'Гниле мiсто', 'UA', None, None, None, 0.0),
#  ('tt1235522', 13, 'Город порока', 'RU', None, None, None, 0.0),
#  ('tt1235522', 14, 'Linha de Ação', 'BR', None, 'imdbDisplay', None, 0.0),
#  ('tt1235522',
#   15,
#   'Emprise sur la ville',
#   'CA',
#   'fr',
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt1235522', 16, 'Ciudad de sombras', 'MX', None, 'imdbDisplay', None, 0.0),
#  ('tt1235522', 17, 'Broken City', 'AR', None, 'imdbDisplay', None, 0.0),
#  ('tt1235522', 18, 'Podkupljeno mesto', 'SI', None, 'imdbDisplay', None, 0.0),
#  ('tt1235522', 19, 'Ciudad de sombras', 'CL', None, 'imdbDisplay', None, 0.0),
#  ('tt1235522', 1, 'Slomljeni grad', 'RS', None, None, None, 0.0),
#  ('tt1235522', 20, 'Slomljeni grad', 'HR', None, 'imdbDisplay', None, 0.0),
#  ('tt1235522', 21, 'Cidade Dividida', 'PT', None, 'imdbDisplay', None, 0.0),
#  ('tt1235522', 22, 'Rikutud linn', 'EE', None, 'imdbDisplay', None, 0.0),
#  ('tt1235522', 23, 'Ir shvura', 'IL', 'he', 'imdbDisplay', None, 0.0),
#  ('tt1235522', 24, 'Orasul corupt', 'RO', None, 'imdbDisplay', None, 0.0),
#  ('tt1235522', 25, 'Bitik Sehir', 'TR', 'tr', 'imdbDisplay', None, 0.0),
#  ('tt1235522', 26, 'Broken City', 'GR', None, 'imdbDisplay', None, 0.0),
#  ('tt1235522', 27, 'Burôkun Shiti', 'JP', None, 'imdbDisplay', None, 0.0),
#  ('tt1235522', 28, 'Władza', 'PL', None, None, None, 0.0),
#  ('tt1235522', 29, 'Broken City', 'PT', None, 'alternative', None, 0.0),
#  ('tt1235522', 2, 'Zlomene mesto', 'CZ', None, 'imdbDisplay', None, 0.0),
#  ('tt1235522', 3, 'Megtört város', 'HU', None, 'imdbDisplay', None, 0.0),
#  ('tt1235522', 4, 'Thành Phô Tôi Ác', 'VN', None, 'imdbDisplay', None, 0.0),
#  ('tt1235522', 5, 'Žlugęs miestas', 'LT', None, None, None, 0.0),
#  ('tt1235522',
#   6,
#   'La trama (Broken City)',
#   'ES',
#   None,
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt1235522', 7, 'Broken City', None, None, 'original', None, 1.0),
#  ('tt1235522', 8, 'Корумпиран град', 'BG', 'bg', None, None, 0.0),
#  ('tt1235522',
#   9,
#   'Broken City - Stadt des Verbrechens',
#   'DE',
#   None,
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt1240538',
#   1,
#   'The Arrested Development Documentary Project',
#   'US',
#   None,
#   None,
#   None,
#   0.0),
#  ('tt1245359', 1, 'Placebo', 'US', None, None, None, 0.0),
#  ('tt1245560', 1, 'Shrink Me', 'US', None, None, None, 0.0),
#  ('tt1247406', 1, 'The Mountain Thief', 'US', None, None, None, 0.0),
#  ('tt1247693', 1, 'Sister Mary', 'US', None, None, None, 0.0),
#  ('tt1248300', 1, 'Rollers', 'US', None, None, None, 0.0),
#  ('tt1252507', 1, 'The Way Home', None, None, 'original', None, 1.0),
#  ('tt1252507', 2, 'El camino a casa', 'ES', None, 'imdbDisplay', None, 0.0),
#  ('tt1252507', 3, 'Resgate De Uma Vida', 'BR', None, 'imdbDisplay', None, 0.0),
#  ('tt1252507', 4, 'The Way Home', 'US', None, None, None, 0.0),
#  ('tt1252507', 5, 'Drumul spre casa', 'RO', None, 'imdbDisplay', None, 0.0),
#  ('tt1252507', 6, 'Our Child Is Missing', 'US', None, 'working', None, 0.0),
#  ('tt1259520', 1, 'Bon appétit', 'CH', 'de', 'imdbDisplay', None, 0.0),
#  ('tt1259520', 2, "Il gusto dell'amore", 'IT', None, 'imdbDisplay', None, 0.0),
#  ('tt1259520', 3, 'Bon appétit', None, None, 'original', None, 1.0),
#  ('tt1259520', 4, 'Приятного аппетита!', 'RU', None, None, None, 0.0),
#  ('tt1259520', 5, 'Bon appétit', 'ES', None, 'imdbDisplay', None, 0.0),
#  ('tt1259520', 6, 'Bon appétit', 'XWW', None, 'imdbDisplay', None, 0.0),
#  ('tt1259520', 7, 'Bon appétit', 'DE', None, 'imdbDisplay', None, 0.0),
#  ('tt1260563', 1, 'Bridge of Names', 'US', None, None, None, 0.0),
#  ('tt1263750', 10, 'Room in Rome', 'DE', None, 'imdbDisplay', None, 0.0),
#  ('tt1263750', 11, 'Atesli oda', 'TR', 'tr', 'imdbDisplay', None, 0.0),
#  ('tt1263750', 12, 'Стая в Рим', 'BG', 'bg', None, None, 0.0),
#  ('tt1263750', 13, 'Room in Rome', 'US', None, 'imdbDisplay', None, 0.0),
#  ('tt1263750', 14, 'Um Quarto em Roma', 'PT', None, 'imdbDisplay', None, 0.0),
#  ('tt1263750', 15, 'Une chambre à Rome', 'CA', 'fr', 'imdbDisplay', None, 0.0),
#  ('tt1263750', 16, 'Eine Nacht in Rom', 'DE', None, 'imdbDisplay', None, 0.0),
#  ('tt1263750', 17, 'Δωμάτιο στη Ρώμη', 'GR', None, None, None, 0.0),
#  ('tt1263750', 18, 'Noc w Rzymie', 'PL', None, 'imdbDisplay', None, 0.0),
#  ('tt1263750', 19, 'Room in Rome', 'XWW', 'en', 'imdbDisplay', None, 0.0),
#  ('tt1263750', 1, 'Комната в Риме', 'RU', None, None, None, 0.0),
#  ('tt1263750', 2, 'Habitación en Roma', None, None, 'original', None, 1.0),
#  ('tt1263750', 3, 'Room in Rome', 'SE', None, 'imdbDisplay', None, 0.0),
#  ('tt1263750', 4, 'Um Quarto em Roma', 'BR', None, 'imdbDisplay', None, 0.0),
#  ('tt1263750', 5, 'Room in Rome', 'FR', None, 'imdbDisplay', None, 0.0),
#  ('tt1263750', 6, 'Habitación en Roma', 'ES', None, 'imdbDisplay', None, 0.0),
#  ('tt1263750', 7, 'Egy éjszaka Rómában', 'HU', None, 'imdbDisplay', None, 0.0),
#  ('tt1263750', 8, 'Domatio sti Romi', 'GR', None, 'imdbDisplay', None, 0.0),
#  ('tt1263750', 9, 'Rom i Roma', 'NO', None, 'imdbDisplay', None, 0.0),
#  ('tt1272039', 1, 'Un Lío en Dólares', 'DO', None, None, None, 0.0),
#  ('tt1272039', 2, 'Un Lío en Dólares', None, None, 'original', None, 1.0),
#  ('tt1272039',
#   3,
#   'A Trouble in Dollars',
#   'US',
#   None,
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt1272051',
#   10,
#   'Zvyozdnye sobaki: Belka i Strelk',
#   'RU',
#   None,
#   'alternative',
#   None,
#   0.0),
#  ('tt1272051',
#   11,
#   'Belka i Strelka. Zvyozdnye sobaki',
#   None,
#   None,
#   'original',
#   None,
#   1.0),
#  ('tt1272051', 12, 'Space Dogs', 'FR', None, 'imdbDisplay', None, 0.0),
#  ('tt1272051',
#   13,
#   'Белка и Стрелка: Звездные собаки',
#   'RU',
#   None,
#   None,
#   None,
#   0.0),
#  ('tt1272051', 14, 'Klavim bahalal', 'IL', 'he', 'imdbDisplay', None, 0.0),
#  ('tt1272051', 15, 'Perros astronautas', 'CL', None, 'imdbDisplay', None, 0.0),
#  ('tt1272051',
#   16,
#   'Biala i Strzala podbijaja kosmos',
#   'PL',
#   None,
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt1272051', 17, 'Space Dogs', 'NO', None, 'imdbDisplay', None, 0.0),
#  ('tt1272051',
#   18,
#   'Câinii stelari: Belka si Strelka',
#   'RO',
#   None,
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt1272051', 19, 'Space Dogs', 'DE', None, 'imdbDisplay', None, 0.0),
#  ('tt1272051', 1, 'Space dogs', 'SE', None, 'imdbDisplay', None, 0.0),
#  ('tt1272051', 20, 'Space Dogs', 'US', None, 'imdbDisplay', None, 0.0),
#  ('tt1272051', 21, 'Cãestronautas', 'BR', None, 'imdbDisplay', None, 0.0),
#  ('tt1272051',
#   22,
#   'Bielka ir Strielka - kosmoso uzkariautojos',
#   'LT',
#   None,
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt1272051',
#   23,
#   'Svemirska avantura 3D',
#   'HR',
#   None,
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt1272051',
#   24,
#   'Kosmosekoerad Belka ja Strelka',
#   'EE',
#   None,
#   None,
#   None,
#   0.0),
#  ('tt1272051',
#   25,
#   'Skylakia sto diastima',
#   'GR',
#   None,
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt1272051',
#   2,
#   'Зорянi собаки: Бiлка та Стрiлка',
#   'UA',
#   None,
#   None,
#   None,
#   0.0),
#  ('tt1272051',
#   3,
#   'Bielka ir Strielka - kosmoso uzkariautojos 3D',
#   'LT',
#   None,
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt1272051', 4, 'Csillagkutyák', 'HU', None, 'imdbDisplay', None, 0.0),
#  ('tt1272051', 5, 'Space Dogs 3D', 'XWW', 'en', None, None, 0.0),
#  ('tt1272051', 6, 'Space Dogs', 'IT', None, 'imdbDisplay', None, 0.0),
#  ('tt1272051', 7, 'Cães Astronautas', 'PT', None, 'imdbDisplay', None, 0.0),
#  ('tt1272051',
#   8,
#   'Mascotas en el espacio',
#   'PE',
#   None,
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt1272051',
#   9,
#   'Zvaigznu suni Belka un Strelka',
#   'LV',
#   None,
#   None,
#   None,
#   0.0),
#  ('tt1277144', 1, 'References', 'US', None, None, None, 0.0),
#  ('tt1277398', 1, 'California Tango', 'US', None, None, None, 0.0),
#  ('tt1277964', 1, 'A Second Life', 'US', None, None, None, 0.0),
#  ('tt1280013', 1, 'Trail of Blood', 'US', None, None, None, 0.0),
#  ('tt1280013', 2, 'Mind Game', 'JP', 'en', None, 'DVD box title', 0.0),
#  ('tt1280013', 3, 'Trail of Blood', None, None, 'original', None, 1.0),
#  ('tt1284451', 1, 'Chokorêto derinjâ', None, None, 'original', None, 1.0),
#  ('tt1284451', 2, 'Chocolate Derringer', 'XWW', 'en', None, None, 0.0),
#  ('tt1284451', 3, 'Chokorêto derinjâ', 'JP', None, None, None, 0.0),
#  ('tt1285245', 1, 'Lahore', 'IN', None, None, None, 0.0),
#  ('tt1288406', 1, 'Life at the Resort', 'US', None, None, None, 0.0),
#  ('tt1288406', 2, 'The Hollywood Resort', 'US', None, 'working', None, 0.0),
#  ('tt1288406', 3, 'Meglepetések napja', 'HU', None, None, None, 0.0),
#  ('tt1288406', 4, 'Life Actually', 'US', None, 'working', None, 0.0),
#  ('tt1288406', 5, 'Life at the Resort', None, None, 'original', None, 1.0),
#  ('tt1288406', 6, 'Zycie w kurorcie', 'PL', None, 'imdbDisplay', None, 0.0),
#  ('tt1288472', 1, 'Left for Dead', 'US', None, None, None, 0.0),
#  ('tt1293751', 1, 'Кастинг', 'RU', None, None, None, 0.0),
#  ('tt1293751',
#   2,
#   'Casting By: Revolution in Hollywood',
#   'US',
#   None,
#   'working',
#   None,
#   0.0),
#  ('tt1293751', 3, 'Κάστινγκ', 'GR', None, None, None, 0.0),
#  ('tt1293751', 4, 'Casting By', None, None, 'original', None, 1.0),
#  ('tt1293751', 5, 'Casting By', 'US', None, None, None, 0.0),
#  ('tt1293751', 6, 'Casting by...', 'FI', None, 'imdbDisplay', None, 0.0),
#  ('tt1293751', 7, 'Filmvärldens okända stjärna', 'SE', None, 'tv', None, 0.0),
#  ('tt1294226', 10, 'The Last Song', None, None, 'original', None, 1.0),
#  ('tt1294226',
#   11,
#   'The Last Song: Ostatnia piosenka',
#   'PL',
#   None,
#   'alternative',
#   None,
#   0.0),
#  ('tt1294226', 12, 'La dernière chanson', 'CA', 'fr', None, None, 0.0),
#  ('tt1294226',
#   13,
#   'Untitled Miley Cyrus Project',
#   'US',
#   None,
#   'working',
#   None,
#   0.0),
#  ('tt1294226', 14, 'La última canción', 'AR', None, None, None, 0.0),
#  ('tt1294226',
#   15,
#   'La dernière chanson',
#   'FR',
#   None,
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt1294226', 16, 'Poslednja pesma', 'RS', None, 'alternative', None, 0.0),
#  ('tt1294226', 17, 'Mit Dir an meiner Seite', 'DE', None, None, None, 0.0),
#  ('tt1294226', 18, 'El último beso', 'PE', None, None, None, 0.0),
#  ('tt1294226',
#   19,
#   'The Last Song - Rakkauden sävelet',
#   'FI',
#   None,
#   'tv',
#   None,
#   0.0),
#  ('tt1294226', 1, 'Poslednja pesem', 'SI', None, 'imdbDisplay', None, 0.0),
#  ('tt1294226', 20, 'Ultimul cântec', 'RO', None, 'imdbDisplay', None, 0.0),
#  ('tt1294226', 21, 'Son sarki', 'TR', 'tr', None, None, 0.0),
#  ('tt1294226', 22, 'Последна песен', 'BG', 'bg', None, None, 0.0),
#  ('tt1294226', 23, 'Viimane laul', 'EE', None, None, None, 0.0),
#  ('tt1294226', 24, 'Последняя песня', 'RU', None, None, None, 0.0),
#  ('tt1294226', 25, 'A Melodia do Adeus', 'PT', None, None, None, 0.0),
#  ('tt1294226',
#   26,
#   'To teleftaio tragoudi',
#   'GR',
#   None,
#   None,
#   'transliterated ISO-LATIN-1 title',
#   0.0),
#  ('tt1294226', 27, 'The Last Song', 'US', None, None, None, 0.0),
#  ('tt1294226', 2, 'La última canción', 'ES', None, 'imdbDisplay', None, 0.0),
#  ('tt1294226', 3, 'Az utolsó dal', 'HU', None, 'imdbDisplay', None, 0.0),
#  ('tt1294226', 4, 'The Last Song', 'FI', None, 'imdbDisplay', None, 0.0),
#  ('tt1294226', 5, 'Το τελευταίο τραγούδι', 'GR', None, None, None, 0.0),
#  ('tt1294226', 6, 'Ostatnia piosenka', 'PL', None, 'imdbDisplay', None, 0.0),
#  ('tt1294226', 7, 'The Last Song', 'DK', None, 'imdbDisplay', None, 0.0),
#  ('tt1294226', 8, 'La ultima canción', 'MX', None, None, None, 0.0),
#  ('tt1294226', 9, 'A Última Música', 'BR', None, None, None, 0.0),
#  ('tt1296373', 1, 'The FP', 'US', None, None, None, 0.0),
#  ('tt1296373', 2, 'The FP', None, None, 'original', None, 1.0),
#  ('tt1296373', 3, 'Фрэйзер Парк', 'RU', None, None, None, 0.0),
#  ('tt1297282', 1, 'The Lady and the Taxi Driver', 'US', None, None, None, 0.0),
#  ('tt1305797', 1, 'Robo', 'IN', 'te', None, 'literal title', 0.0),
#  ('tt1305797', 2, 'Endhiran', 'IN', 'ta', 'working', None, 0.0),
#  ('tt1305797', 3, 'The Robot', 'XEU', 'en', 'alternative', None, 0.0),
#  ('tt1305797', 4, 'Robot', 'IN', 'hi', None, 'dubbed version', 0.0),
#  ('tt1305797', 5, 'Enthiran', 'IN', None, None, None, 0.0),
#  ('tt1305797', 6, 'Robot', 'FI', None, 'imdbDisplay', None, 0.0),
#  ('tt1305797', 7, 'Enthiran', None, None, 'original', None, 1.0),
#  ('tt1305797', 8, 'Робот', 'RU', None, None, None, 0.0),
#  ('tt1305797', 9, 'Robot', 'US', None, None, 'literal English title', 0.0),
#  ('tt1308729', 10, 'Bullet', 'JP', 'en', 'imdbDisplay', None, 0.0),
#  ('tt1308729', 11, 'Metak u glavu', 'HR', None, 'imdbDisplay', None, 0.0),
#  ('tt1308729', 12, 'Kula w łeb', 'PL', None, None, None, 0.0),
#  ('tt1308729',
#   13,
#   'El Ejecutor',
#   'VE',
#   None,
#   None,
#   'alternative transliteration',
#   0.0),
#  ('tt1308729', 14, 'El ejecutor', 'MX', None, 'imdbDisplay', None, 0.0),
#  ('tt1308729', 15, 'Kulką i kaktą', 'LT', None, None, None, 0.0),
#  ('tt1308729', 16, 'Bullet to the Head', 'NL', None, 'dvd', None, 0.0),
#  ('tt1308729', 17, 'El ejecutor', 'AR', None, 'imdbDisplay', None, 0.0),
#  ('tt1308729', 18, 'Glonţ în cap', 'RO', None, None, None, 0.0),
#  ('tt1308729', 19, 'Intikam Kursunu', 'TR', 'tr', 'imdbDisplay', None, 0.0),
#  ('tt1308729', 1, 'El ejecutor', 'CO', None, None, 'new title', 0.0),
#  ('tt1308729', 20, 'El ejecutor', 'PE', None, 'imdbDisplay', None, 0.0),
#  ('tt1308729', 21, 'Куршум в главата', 'BG', 'bg', None, None, 0.0),
#  ('tt1308729',
#   22,
#   'Shootout - Keine Gnade',
#   'DE',
#   None,
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt1308729', 23, 'Alvo Duplo', 'BR', None, 'imdbDisplay', None, 0.0),
#  ('tt1308729',
#   24,
#   'Du plomb dans la tête',
#   'CA',
#   'fr',
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt1308729', 25, 'Bullet to the Head', None, None, 'original', None, 1.0),
#  ('tt1308729', 26, 'Metak u glavu', 'RS', None, None, None, 0.0),
#  ('tt1308729', 27, 'Baretto', 'JP', None, 'imdbDisplay', None, 0.0),
#  ('tt1308729', 28, 'El ejecutor', 'UY', None, None, 'dubbed version', 0.0),
#  ('tt1308729', 29, 'Bala Certeira', 'PT', None, 'imdbDisplay', None, 0.0),
#  ('tt1308729', 2, 'Fejlövés', 'HU', None, 'imdbDisplay', None, 0.0),
#  ('tt1308729', 30, 'Неудержимый', 'RU', None, None, None, 0.0),
#  ('tt1308729', 3, "Kadur ba'rosh", 'IL', 'he', 'imdbDisplay', None, 0.0),
#  ('tt1308729', 4, 'Bullet to the Head', 'US', None, None, None, 0.0),
#  ('tt1308729', 5, 'Kuul pähe', 'EE', None, 'imdbDisplay', None, 0.0),
#  ('tt1308729',
#   6,
#   'Du plomb dans la tête',
#   'FR',
#   None,
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt1308729', 7, 'Headshot', 'US', None, 'working', None, 0.0),
#  ('tt1308729',
#   8,
#   'Jimmy Bobo - Bullet to the Head',
#   'IT',
#   None,
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt1308729',
#   9,
#   'Una bala en la cabeza',
#   'ES',
#   None,
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt1309561',
#   1,
#   'Lamhaa: The Untold Story of Kashmir',
#   'IN',
#   None,
#   None,
#   None,
#   0.0),
#  ('tt1309561', 2, 'Lamhaa', 'IN', 'hi', None, 'short title', 0.0),
#  ('tt1309561',
#   3,
#   'Lamhaa: The Untold Story of Kashmir',
#   None,
#   None,
#   'original',
#   None,
#   1.0),
#  ('tt1321874', 1, 'Zombies Unleashed', 'US', None, None, None, 0.0),
#  ('tt1322257', 1, '0-800-Love', 'GB', None, 'working', None, 0.0),
#  ('tt1322257', 2, 'Ложь во спасение', 'RU', None, None, None, 0.0),
#  ('tt1322257', 3, 'Jhootha Hi Sahi', None, None, 'original', None, 1.0),
#  ('tt1322257', 4, 'Jhootha Hi Sahi', 'IN', None, None, None, 0.0),
#  ('tt1322257', 5, '1-800-LOVE', 'IN', 'en', 'working', None, 0.0),
#  ('tt1322257',
#   6,
#   'Call Me Dil',
#   'IN',
#   'hi',
#   None,
#   'alternative spelling',
#   0.0),
#  ('tt1322384', 1, 'SubHysteria', 'US', None, None, None, 0.0),
#  ('tt1326949', 1, 'Mark My Words', 'US', None, None, None, 0.0),
#  ('tt1327176', 1, 'Claustrophobia', 'US', None, None, None, 0.0),
#  ('tt1329330', 1, 'Yeardley', None, None, 'original', None, 1.0),
#  ('tt1329330', 2, 'The Clockwise Family', 'US', None, 'working', None, 0.0),
#  ('tt1329330', 3, 'Yeardley', 'US', None, None, None, 0.0),
#  ('tt1336601', 1, 'Die Meute', 'DE', None, None, None, 0.0),
#  ('tt1336601', 2, 'Ölüm Çiftligi', 'TR', 'tr', 'imdbDisplay', None, 0.0),
#  ('tt1336601', 3, 'La meute', None, None, 'original', None, 1.0),
#  ('tt1336601', 4, 'La meute', 'FR', None, None, None, 0.0),
#  ('tt1336601', 5, 'The Pack', 'XWW', 'en', None, None, 0.0),
#  ('tt1336601', 6, 'Свора', 'RU', None, None, None, 0.0),
#  ('tt1336601', 7, 'Paket', 'HR', None, 'imdbDisplay', None, 0.0),
#  ('tt1336601', 8, 'The Pack', 'SE', None, 'imdbDisplay', None, 0.0),
#  ('tt1340700', 1, 'Back on Earth', 'AU', None, None, None, 0.0),
#  ('tt1340801', 1, 'Ubit korolya', 'RU', None, 'working', None, 0.0),
#  ('tt1340801', 2, 'Blizkiy vrag', None, None, 'original', None, 1.0),
#  ('tt1340801', 3, 'Bliski wróg', 'PL', None, 'imdbDisplay', None, 0.0),
#  ('tt1340801', 4, 'Близкий Враг', 'RU', None, None, None, 0.0),
#  ('tt1340801', 5, 'Close Enemy', 'XWW', 'en', None, None, 0.0),
#  ('tt1340839',
#   1,
#   'Sacred & Secret - Das geheime Bali',
#   'CH',
#   'de',
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt1340839',
#   2,
#   "Sacré & secret: L'âme de Bali",
#   'CH',
#   'fr',
#   None,
#   'DVD box title',
#   0.0),
#  ('tt1340839', 3, 'Sacred & Secret', None, None, 'original', None, 1.0),
#  ('tt1343092', 10, 'Der große Gatsby', 'DE', None, 'imdbDisplay', None, 0.0),
#  ('tt1343092', 11, 'Velký Gatsby', 'CZ', None, 'imdbDisplay', None, 0.0),
#  ('tt1343092', 12, 'Veliki Gatsby', 'SI', 'sl', 'imdbDisplay', None, 0.0),
#  ('tt1343092', 13, 'The Great Gatsby', 'US', None, 'imdbDisplay', None, 0.0),
#  ('tt1343092', 14, 'Veliki Gatsby', 'SI', None, 'imdbDisplay', None, 0.0),
#  ('tt1343092', 15, 'El gran Gatsby', 'VE', None, 'imdbDisplay', None, 0.0),
#  ('tt1343092', 16, 'El gran Gatsby', 'MX', None, 'imdbDisplay', None, 0.0),
#  ('tt1343092', 17, 'Suur Gatsby', 'EE', None, 'imdbDisplay', None, 0.0),
#  ('tt1343092', 18, 'The Great Gatsby', None, None, 'original', None, 1.0),
#  ('tt1343092', 19, 'Великий Гэтсби', 'RU', None, None, None, 0.0),
#  ('tt1343092', 1, 'Didi getsbi', 'GE', None, 'imdbDisplay', None, 0.0),
#  ('tt1343092', 20, 'El gran Gatsby', 'PE', None, 'imdbDisplay', None, 0.0),
#  ('tt1343092', 21, 'Великият Гетсби', 'BG', 'bg', None, None, 0.0),
#  ('tt1343092', 22, 'O Grande Gatsby', 'PT', None, 'imdbDisplay', None, 0.0),
#  ('tt1343092',
#   23,
#   'Gatsby le magnifique',
#   'CA',
#   'fr',
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt1343092', 24, 'Il grande Gatsby', 'IT', None, 'imdbDisplay', None, 0.0),
#  ('tt1343092', 25, 'O Grande Gatsby', 'BR', None, 'imdbDisplay', None, 0.0),
#  ('tt1343092', 26, 'Den store Gatsby', 'SE', None, 'imdbDisplay', None, 0.0),
#  ('tt1343092', 27, 'El gran Gatsby', 'CL', None, 'imdbDisplay', None, 0.0),
#  ('tt1343092', 28, 'Wielki Gatsby', 'PL', None, 'imdbDisplay', None, 0.0),
#  ('tt1343092', 29, 'Ο υπέροχος Γκάτσμπυ', 'GR', None, None, None, 0.0),
#  ('tt1343092', 2, 'Veliki Getsbi', 'RS', None, None, None, 0.0),
#  ('tt1343092', 30, 'A nagy Gatsby', 'HU', None, 'imdbDisplay', None, 0.0),
#  ('tt1343092', 31, 'Veliki Gatsby', 'HR', None, 'imdbDisplay', None, 0.0),
#  ('tt1343092', 32, 'El gran Gatsby', 'ES', None, 'imdbDisplay', None, 0.0),
#  ('tt1343092', 33, 'El gran Gatsby', 'BO', None, 'imdbDisplay', None, 0.0),
#  ('tt1343092', 34, 'Den store Gatsby', 'DK', None, 'imdbDisplay', None, 0.0),
#  ('tt1343092', 35, 'Den store Gatsby', 'NO', None, 'imdbDisplay', None, 0.0),
#  ('tt1343092', 36, 'Великий Гетсбi', 'UA', None, None, None, 0.0),
#  ('tt1343092', 37, "Gatsby ha'gadol", 'IL', 'he', 'imdbDisplay', None, 0.0),
#  ('tt1343092', 38, 'Lielais Getsbijs', 'LV', None, 'imdbDisplay', None, 0.0),
#  ('tt1343092',
#   39,
#   'O yperohos Gatsby',
#   'GR',
#   None,
#   None,
#   'transliterated ISO-LATIN-1 title',
#   0.0),
#  ('tt1343092', 3, 'Marele Gatsby', 'RO', None, 'imdbDisplay', None, 0.0),
#  ('tt1343092', 4, 'The Great Gatsby', 'AU', None, None, None, 0.0),
#  ('tt1343092', 5, 'Didysis Getsbis', 'LT', None, 'imdbDisplay', None, 0.0),
#  ('tt1343092',
#   6,
#   'The Great Gatsby - Kultahattu',
#   'FI',
#   None,
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt1343092', 7, 'Muhtesem Gatsby', 'TR', 'tr', 'imdbDisplay', None, 0.0),
#  ('tt1343092',
#   8,
#   'Gatsby le magnifique',
#   'FR',
#   None,
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt1343092', 9, 'El gran Gatsby', 'AR', None, 'imdbDisplay', None, 0.0),
#  ('tt1343727', 10, 'Дред 3D', 'BG', 'bg', None, None, 0.0),
#  ('tt1343727', 11, 'Judge Dredd', 'JP', 'en', 'imdbDisplay', None, 0.0),
#  ('tt1343727', 12, 'Dredd', 'DE', None, 'imdbDisplay', None, 0.0),
#  ('tt1343727', 13, 'Sudija Dred', 'RS', None, 'imdbDisplay', None, 0.0),
#  ('tt1343727', 14, 'Dredd', 'US', None, 'alternative', None, 0.0),
#  ('tt1343727', 15, 'Суддя Дредд', 'UA', None, None, None, 0.0),
#  ('tt1343727', 16, 'Судья Дредд 3D', 'RU', None, None, None, 0.0),
#  ('tt1343727', 17, 'Dredd', None, None, 'original', None, 1.0),
#  ('tt1343727',
#   18,
#   'Dredd: O Juiz do Apocalipse',
#   'BR',
#   None,
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt1343727', 19, 'Dredd', 'ES', None, 'imdbDisplay', None, 0.0),
#  ('tt1343727', 1, 'Dredd', 'FR', None, 'dvd', None, 0.0),
#  ('tt1343727', 20, 'Dredd 3D', 'PL', None, 'imdbDisplay', None, 0.0),
#  ('tt1343727', 21, 'Dredd', 'UY', None, 'imdbDisplay', None, 0.0),
#  ('tt1343727', 22, 'Dredd 3D', 'GB', None, None, 'promotional title', 0.0),
#  ('tt1343727', 23, 'Dredd', 'CA', 'fr', 'imdbDisplay', None, 0.0),
#  ('tt1343727', 24, 'Dredd', 'FI', None, 'dvd', None, 0.0),
#  ('tt1343727', 25, 'Judge Dredd', 'JM', 'en', 'imdbDisplay', None, 0.0),
#  ('tt1343727', 26, 'Dredd', 'DK', None, 'imdbDisplay', None, 0.0),
#  ('tt1343727', 27, "Ha'shofet Dredd", 'IL', 'he', 'imdbDisplay', None, 0.0),
#  ('tt1343727', 28, 'Yargiç Dredd', 'TR', 'tr', 'imdbDisplay', None, 0.0),
#  ('tt1343727', 29, 'Dredd', 'GB', None, None, None, 0.0),
#  ('tt1343727', 2, 'Dredas', 'LT', None, 'imdbDisplay', None, 0.0),
#  ('tt1343727',
#   30,
#   "Dredd - Il giudice dell'apocalisse",
#   'IT',
#   None,
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt1343727', 31, 'Judge Dredd', 'GB', None, 'working', None, 0.0),
#  ('tt1343727',
#   32,
#   'Dredd 3D: Ultima judecata',
#   'RO',
#   None,
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt1343727', 3, 'Dredd 3D', 'FI', None, 'imdbDisplay', None, 0.0),
#  ('tt1343727', 4, 'Dredd', 'GR', None, None, 'poster title', 0.0),
#  ('tt1343727', 5, 'Dredd', 'MX', None, 'imdbDisplay', None, 0.0),
#  ('tt1343727', 6, 'Dredd', 'BR', None, 'imdbDisplay', None, 0.0),
#  ('tt1343727', 7, 'Dredd', 'AR', None, 'imdbDisplay', None, 0.0),
#  ('tt1343727', 8, 'Dredd', 'PT', None, 'imdbDisplay', None, 0.0),
#  ('tt1343727', 9, 'Ντρεντ', 'GR', None, None, None, 0.0),
#  ('tt1344670', 1, 'Teenagers', 'FR', None, None, None, 0.0),
#  ('tt1346308',
#   1,
#   'The Rescuers: Heroes of the Holocaust',
#   'US',
#   None,
#   None,
#   'promotional title',
#   0.0),
#  ('tt1346308', 2, 'The Rescuers', None, None, 'original', None, 1.0),
#  ('tt1346308', 3, 'The Rescuers', 'US', None, None, None, 0.0),
#  ('tt1351784', 1, 'Psychosis', None, None, 'original', None, 1.0),
#  ('tt1351784', 2, 'Vivid', 'GB', None, 'working', None, 0.0),
#  ('tt1351784', 3, 'Psychosis', 'MX', None, 'imdbDisplay', None, 0.0),
#  ('tt1351784', 4, 'Psychosis', 'GB', None, None, None, 0.0),
#  ('tt1351784',
#   5,
#   'Una casa en las afueras',
#   'ES',
#   None,
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt1351784', 6, 'Психоз', 'RU', None, None, None, 0.0),
#  ('tt1351784', 7, 'Efialtes', 'GR', None, 'dvd', None, 0.0),
#  ('tt1351784',
#   8,
#   "Psychosis: La Mort dans l'Ame",
#   'FR',
#   None,
#   None,
#   'DVD box title',
#   0.0),
#  ('tt1371160', 1, 'The Kid', 'GB', None, None, None, 0.0),
#  ('tt1371160', 2, 'The Kid', None, None, 'original', None, 1.0),
#  ('tt1371160', 3, 'Дитя', 'RU', None, None, None, 0.0),
#  ('tt1384356', 1, 'Land of the Rising Fastball', 'US', None, None, None, 0.0),
#  ('tt1386691', 1, 'Shimmer Lake', 'CA', None, None, None, 0.0),
#  ('tt1386691', 2, 'Shimmer Lake', 'BR', None, None, 'cable TV title', 0.0),
# ...
#  ('tt1570091', 3, 'Før og efter', 'DK', None, 'working', None, 0.0),
#  ('tt1570091', 4, 'Hold Me Tight', 'SE', None, 'imdbDisplay', None, 0.0),
#  ('tt1570091', 5, 'Hold om mig', None, None, 'original', None, 1.0),
#  ('tt1570091', 6, 'Przytul mnie', 'PL', None, 'imdbDisplay', None, 0.0),
#  ('tt1570091', 7, 'Hold om mig', 'DK', None, None, None, 0.0),
#  ('tt1570417', 1, 'Accident on Hill Road', 'IN', None, None, None, 0.0),
#  ('tt1571235',
#   1,
#   'The Lady Shogun and Her Men',
#   'XWW',
#   'en',
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt1571235', 2, 'Ôoku', None, None, 'original', None, 1.0),
#  ('tt1571235', 3, 'Ôoku', 'JP', None, None, None, 0.0),
#  ('tt1571409', 1, 'Parkirani', 'RS', None, 'imdbDisplay', None, 0.0),
#  ('tt1571409', 2, 'Parkolópályán', 'HU', None, None, None, 0.0),
#  ('tt1571409', 3, 'Parked - Gestrandet', 'DE', None, 'imdbDisplay', None, 0.0),
#  ('tt1571409', 4, 'Jumissa', 'FI', None, None, None, 0.0),
#  ('tt1571409', 5, 'Parked', 'IE', None, None, None, 0.0),
#  ('tt1571409', 6, 'Parked', None, None, 'original', None, 1.0),
#  ('tt1571409', 7, 'Припаркованные', 'RU', None, None, None, 0.0),
#  ('tt1571409', 8, 'Припаркованi', 'UA', None, None, None, 0.0),
#  ('tt1571409', 9, 'Zaparkowany', 'PL', None, 'imdbDisplay', None, 0.0),
#  ('tt1572315',
#   10,
#   'Masacre en Texas: Herencia maldita',
#   'AR',
#   None,
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt1572315',
#   11,
#   'Texas Chainsaw 5',
#   'US',
#   None,
#   None,
#   'informal alternative title',
#   0.0),
#  ('tt1572315', 12, 'Texas Chainsaw 3D', 'US', None, None, None, 0.0),
#  ('tt1572315',
#   13,
#   'Massacre à la tronçonneuse',
#   'CA',
#   'fr',
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt1572315',
#   14,
#   'Техаська рiзанина бензопилою 3D',
#   'UA',
#   None,
#   None,
#   None,
#   0.0),
#  ('tt1572315',
#   15,
#   'Texas Chainsaw: O Massacre',
#   'PT',
#   None,
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt1572315',
#   16,
#   'Teksaški masakr motornom pilom 3D',
#   'HR',
#   None,
#   None,
#   None,
#   0.0),
#  ('tt1572315', 17, 'Teksas Katliami', 'TR', 'tr', 'imdbDisplay', None, 0.0),
#  ('tt1572315',
#   18,
#   'Teksaski pokol z motorko 3D',
#   'SI',
#   None,
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt1572315',
#   19,
#   'Masacrul din Texas 3D',
#   'RO',
#   None,
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt1572315', 1, 'Ο δολοφόνος με το πριόνι', 'GR', None, None, None, 0.0),
#  ('tt1572315',
#   20,
#   'Texas Chainsaw Massacre 3D',
#   'SE',
#   None,
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt1572315',
#   21,
#   'Non aprite quella porta 3D',
#   'IT',
#   None,
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt1572315', 22, 'Texas Chainsaw 3D', 'FR', None, 'imdbDisplay', None, 0.0),
#  ('tt1572315', 23, 'Texas Chainsaw', 'US', None, 'dvd', None, 0.0),
#  ('tt1572315',
#   24,
#   'La matanza de Texas 3D',
#   'ES',
#   None,
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt1572315',
#   25,
#   "Ha'menasrim mi'Texas 3D",
#   'IL',
#   'he',
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt1572315',
#   26,
#   'Teksaški masakr motornom testerom 3D',
#   'RS',
#   None,
#   None,
#   None,
#   0.0),
#  ('tt1572315', 27, 'Тексаско клане 3', 'BG', 'bg', None, None, 0.0),
#  ('tt1572315',
#   28,
#   'Kolai Veriyan 3D',
#   'IN',
#   'ta',
#   None,
#   'dubbed version',
#   0.0),
#  ('tt1572315',
#   29,
#   'O Massacre da Serra Elétrica 3D: A Lenda Continua',
#   'BR',
#   None,
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt1572315',
#   2,
#   'La masacre de Texas 3D',
#   'PE',
#   None,
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt1572315',
#   30,
#   'O dolofonos me to prioni',
#   'GR',
#   None,
#   None,
#   'transliterated ISO-LATIN-1 title',
#   0.0),
#  ('tt1572315', 31, 'Texas Chainsaw 2D', 'DE', None, 'alternative', None, 0.0),
#  ('tt1572315',
#   32,
#   'Техасская резня бензопилой 3D',
#   'RU',
#   None,
#   None,
#   None,
#   0.0),
#  ('tt1572315',
#   33,
#   'Masacre en Texas: herencia maldita',
#   'MX',
#   None,
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt1572315',
#   34,
#   'Texase mootorsaemõrvad 3D',
#   'EE',
#   None,
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt1572315',
#   3,
#   'Texasin moottorisahamurhat',
#   'FI',
#   None,
#   None,
#   'informal title',
#   0.0),
#  ('tt1572315',
#   4,
#   'A texasi láncfűrészes: Az örökség',
#   'HU',
#   None,
#   None,
#   None,
#   0.0),
#  ('tt1572315', 5, 'Texas Chainsaw 3D', None, None, 'original', None, 1.0),
#  ('tt1572315', 6, 'Texas Chainsaw', 'GB', None, 'tv', None, 0.0),
#  ('tt1572315',
#   7,
#   'Texaský masakr motorovou pilou 3D',
#   'CZ',
#   None,
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt1572315', 8, 'Piła mechaniczna', 'PL', None, None, None, 0.0),
#  ('tt1572315',
#   9,
#   'Texas Chainsaw Massacre 5',
#   'US',
#   None,
#   'working',
#   None,
#   0.0),
#  ('tt1572781',
#   10,
#   'Suzumiya Haruhi no shôshitsu',
#   None,
#   None,
#   'original',
#   None,
#   1.0),
#  ('tt1572781',
#   11,
#   'Das Verschwinden der Haruhi Suzumiya',
#   'DE',
#   None,
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt1572781', 1, 'Suzumiya Haruhi no shôshitsu', 'JP', None, None, None, 0.0),
#  ('tt1572781', 2, 'Исчезновение Харухи Судзумии', 'RU', None, None, None, 0.0),
#  ('tt1572781',
#   3,
#   'La disparition de Haruhi Suzumiya',
#   'FR',
#   None,
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt1572781',
#   4,
#   'The Disappearance of Haruhi Suzumiya',
#   'XWW',
#   'en',
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt1572781',
#   5,
#   'La Desaparición de Suzumiya Haruhi',
#   'ES',
#   None,
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt1572781',
#   6,
#   'The Vanishment of Haruhi Suzumiya',
#   'XWW',
#   'en',
#   None,
#   'informal literal English title',
#   0.0),
#  ('tt1572781',
#   7,
#   'La Desaparición de Haruhi Suzumiya',
#   'AR',
#   None,
#   'alternative',
#   None,
#   0.0),
#  ('tt1572781',
#   8,
#   'La Desaparición de Haruhi Suzumiya',
#   'XSA',
#   'es',
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt1572781',
#   9,
#   'La scomparsa di Haruhi Suzumiya',
#   'IT',
#   None,
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt1577072', 1, 'The Beast of Bottomless Lake', 'CA', None, None, None, 0.0),
#  ('tt1581846', 1, 'Tribe', 'GB', None, None, None, 0.0),
#  ('tt1582207',
#   1,
#   'The Little Gem',
#   'GB',
#   None,
#   None,
#   'literal English title',
#   0.0),
#  ('tt1582207', 2, 'The Jewel', 'XWW', 'en', 'imdbDisplay', None, 0.0),
#  ('tt1582207', 3, 'Конфетка', 'RU', None, None, None, 0.0),
#  ('tt1582207', 4, 'Cacko', 'PL', None, 'imdbDisplay', None, 0.0),
#  ('tt1582207',
#   5,
#   "L'empire des Rastelli",
#   'FR',
#   None,
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt1582207', 6, 'Il gioiellino', 'IT', None, None, None, 0.0),
#  ('tt1582207', 7, 'Il gioiellino', None, None, 'original', None, 1.0),
#  ('tt1582383', 1, 'Pame gia record', 'GR', None, 'festival', None, 0.0),
#  ('tt1582383', 2, 'Breaking and Entering', 'US', None, None, None, 0.0),
#  ('tt1582383', 3, 'Breaking and Entering', None, None, 'original', None, 1.0),
#  ('tt1582526', 1, 'Kotha Bandham', None, None, 'original', None, 1.0),
#  ('tt1582526', 2, 'Kotha Bandham', 'IN', None, None, None, 0.0),
#  ('tt1582526',
#   3,
#   'Collector Gaari Bharya',
#   None,
#   None,
#   None,
#   'new title',
#   0.0),
#  ('tt1584798', 1, 'Kazura', None, None, 'original', None, 1.0),
#  ('tt1584798', 2, 'Wig', 'XWW', 'en', 'festival', None, 0.0),
#  ('tt1584798', 3, 'Kazura', 'JP', None, None, None, 0.0),
#  ('tt1586523', 1, 'Racing Roman', 'US', None, None, None, 0.0),
#  ('tt1587139', 1, 'Jens Pulver: Driven', 'US', None, None, None, 0.0),
#  ('tt1587156',
#   1,
#   'Gekijouban Fate/stay night: Unlimited Blade Works',
#   None,
#   None,
#   'original',
#   None,
#   1.0),
#  ('tt1587156',
#   2,
#   'Gekijouban Fate/stay night: Unlimited Blade Works',
#   'JP',
#   None,
#   None,
#   None,
#   0.0),
#  ('tt1587156', 3, 'Fate/Stay Night', 'DE', None, 'imdbDisplay', None, 0.0),
#  ('tt1587298', 1, 'Yûkai Rhapsody', 'JP', None, None, None, 0.0),
#  ('tt1587298', 2, 'Yûkai Rhapsody', None, None, 'original', None, 1.0),
#  ('tt1587298', 3, 'Accidental Kidnapper', 'XWW', 'en', None, None, 0.0),
#  ('tt1587436', 1, 'Verlaine', 'US', None, 'working', None, 0.0),
#  ('tt1587436', 2, 'Crosshairs', None, None, 'original', None, 1.0),
#  ('tt1587436', 3, 'Crosshairs', 'US', None, None, None, 0.0),
#  ('tt1587878', 1, 'Tuan yuan', None, None, 'original', None, 1.0),
#  ('tt1587878', 2, 'Apart Together', 'FR', None, 'imdbDisplay', None, 0.0),
#  ('tt1587878', 3, 'Tuan yuan', 'CN', None, None, None, 0.0),
#  ('tt1587878', 4, 'Razem i osobno', 'PL', None, 'imdbDisplay', None, 0.0),
#  ('tt1587878', 5, 'Apart Together', 'XWW', 'en', None, None, 0.0),
#  ('tt1587878', 6, 'Getrennt zusammen', 'DE', None, 'imdbDisplay', None, 0.0),
#  ('tt1587878', 7, 'Χωριστά Μαζί', 'GR', None, None, None, 0.0),
#  ('tt1588880', 1, 'Matki', 'PL', None, 'imdbDisplay', None, 0.0),
#  ('tt1588880', 2, 'Majke', 'RS', None, 'imdbDisplay', None, 0.0),
#  ('tt1588880', 3, 'Majki', None, None, 'original', None, 1.0),
#  ('tt1588880', 4, 'Матери', 'RU', None, None, None, 0.0),
#  ('tt1588880', 5, 'Anyák', 'HU', None, 'imdbDisplay', None, 0.0),
#  ('tt1588880', 6, 'Майки', 'BG', 'bg', None, None, 0.0),
#  ('tt1588880', 7, 'Majki', 'MK', None, 'alternative', None, 0.0),
#  ('tt1588880', 8, 'Like a Baby', 'MK', None, 'working', None, 0.0),
#  ('tt1588880', 9, 'Mothers', 'XWW', 'en', 'imdbDisplay', None, 0.0),
#  ('tt1590020',
#   1,
#   'Eleganten från vidderna - filmen om Eddie Meduza',
#   None,
#   None,
#   'original',
#   None,
#   1.0),
#  ('tt1590020', 2, 'Eddie Meduza: The Movie', 'XWW', 'en', None, None, 0.0),
#  ('tt1590020',
#   3,
#   'Eleganten från vidderna - filmen om Eddie Meduza',
#   'SE',
#   None,
#   None,
#   None,
#   0.0),
#  ('tt1590796', 1, 'Mutant Girls Squad', 'DE', None, 'imdbDisplay', None, 0.0),
#  ('tt1590796', 2, 'Mutant Girls Squad', 'SE', None, 'imdbDisplay', None, 0.0),
#  ('tt1590796',
#   3,
#   'Sentô shôjo: Chi no tekkamen densetsu',
#   None,
#   None,
#   'original',
#   None,
#   1.0),
#  ('tt1590796', 4, 'Отряд девушек-мутантов', 'RU', None, None, None, 0.0),
#  ('tt1590796',
#   5,
#   'Sentô shôjo: Chi no tekkamen densetsu',
#   'JP',
#   None,
#   None,
#   None,
#   0.0),
#  ('tt1590796', 6, 'Mutant Girls Squad', 'XWW', 'en', None, None, 0.0),
#  ('tt1590796', 7, 'Mutant Girls Squad', 'IT', None, 'imdbDisplay', None, 0.0),
#  ('tt1590941', 1, '18+', 'ID', None, None, None, 0.0),
#  ('tt1592503', 1, 'Alien vs. Ninja', None, None, 'original', None, 1.0),
#  ('tt1592503', 2, 'Чyжие против ниндзя', 'RU', None, None, None, 0.0),
#  ('tt1592503', 3, 'AvN: Alien vs. Ninja', 'AU', None, 'dvd', None, 0.0),
#  ('tt1592503', 4, 'Ninja contro Alieni', 'IT', None, 'imdbDisplay', None, 0.0),
#  ('tt1592503', 5, 'Alien vs. Ninja', 'JP', None, None, None, 0.0),
#  ('tt1593300', 1, 'Scumrun II', 'GB', None, None, None, 0.0),
#  ('tt1594555', 1, 'Susa', 'GE', None, None, None, 0.0),
#  ('tt1594555', 2, 'Susa', None, None, 'original', None, 1.0),
#  ('tt1594555', 3, 'Суса', 'RU', None, None, None, 0.0),
#  ('tt1600428', 1, 'No et moi', 'FR', None, None, None, 0.0),
#  ('tt1600428', 2, 'No et moi', None, None, 'original', None, 1.0),
#  ('tt1600428',
#   3,
#   'No and Me',
#   'XWW',
#   'en',
#   None,
#   'promotional abbreviation',
#   0.0),
#  ('tt1600428', 4, 'No et moi', 'CA', 'fr', 'imdbDisplay', None, 0.0),
#  ('tt1601455', 1, 'Schnupfen im Kopf', None, None, 'original', None, 1.0),
#  ('tt1601455', 2, 'Head Cold', 'XWW', 'en', None, None, 0.0),
#  ('tt1601455', 3, 'Hideg fejjel', 'HU', None, 'imdbDisplay', None, 0.0),
#  ('tt1601455', 4, 'Schnupfen im Kopf', 'DE', None, None, None, 0.0),
#  ('tt1602476', 1, 'Компания негодяев', 'RU', None, None, None, 0.0),
#  ('tt1602476', 2, 'Badmaa$h Company', None, None, 'original', None, 1.0),
#  ('tt1602476',
#   3,
#   'Badmaash Company',
#   'IN',
#   'en',
#   None,
#   'alternative spelling',
#   0.0),
#  ('tt1602476', 4, 'Badmaa$h Company', 'IN', None, None, None, 0.0),
#  ('tt1602476',
#   5,
#   'Badmaash Company',
#   'IN',
#   'hi',
#   None,
#   'alternative spelling',
#   0.0),
#  ('tt1602563', 1, 'Night of the Loup Garou', 'US', None, None, None, 0.0),
#  ('tt1602613',
#   10,
#   'Apenas Deus Perdoa',
#   'BR',
#   None,
#   None,
#   'cable TV title',
#   0.0),
#  ('tt1602613', 11, 'Μόνο ο Θεός συγχωρεί', 'GR', None, None, None, 0.0),
#  ('tt1602613', 12, 'Seul dieu pardonne', 'CA', 'fr', 'imdbDisplay', None, 0.0),
#  ('tt1602613', 13, 'Tylko Bóg wybacza', 'PL', None, 'imdbDisplay', None, 0.0),
#  ('tt1602613', 14, 'Mono o Theos syghorei', 'GR', None, 'dvd', None, 0.0),
#  ('tt1602613',
#   15,
#   'Solo Dio perdona - Only God Forgives',
#   'IT',
#   None,
#   None,
#   'poster title',
#   0.0),
#  ('tt1602613', 16, 'Only God Forgives', None, None, 'original', None, 1.0),
#  ('tt1602613', 17, 'Sólo Dios perdona', 'MX', None, 'imdbDisplay', None, 0.0),
#  ('tt1602613', 18, 'Samo Bog prašta', 'RS', None, None, None, 0.0),
#  ('tt1602613', 19, 'Only God Forgives', 'DK', None, None, None, 0.0),
#  ('tt1602613', 1, 'Só Deus Perdoa', 'BR', None, 'imdbDisplay', None, 0.0),
#  ('tt1602613', 20, 'Само Бог прощава', 'BG', 'bg', None, None, 0.0),
#  ('tt1602613',
#   21,
#   'Ainult Jumal andestab',
#   'EE',
#   None,
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt1602613',
#   22,
#   'Atleidzia tik Dievas',
#   'LT',
#   None,
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt1602613', 23, 'Only God', 'JP', 'en', 'imdbDisplay', None, 0.0),
#  ('tt1602613', 24, 'Só Deus Perdoa', 'PT', None, 'imdbDisplay', None, 0.0),
#  ('tt1602613', 25, 'Sólo Dios perdona', 'ES', None, 'imdbDisplay', None, 0.0),
#  ('tt1602613', 26, 'Onrî goddo', 'JP', None, 'imdbDisplay', None, 0.0),
#  ('tt1602613', 27, 'Samo bog odpusca', 'SI', None, 'imdbDisplay', None, 0.0),
#  ('tt1602613',
#   28,
#   "Rak elohim sol'e'ah",
#   'IL',
#   'he',
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt1602613',
#   29,
#   'Csak Isten bocsáthat meg',
#   'HU',
#   None,
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt1602613',
#   2,
#   'Numai Dumnezeu iartã',
#   'RO',
#   None,
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt1602613', 30, 'Solo Dio perdona', 'IT', None, 'imdbDisplay', None, 0.0),
#  ('tt1602613', 31, 'Только Бог простит', 'RU', None, None, None, 0.0),
#  ('tt1602613',
#   32,
#   'Sadece Tanri Affeder',
#   'TR',
#   'tr',
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt1602613', 3, 'Лише Бог прощае', 'UA', None, None, None, 0.0),
#  ('tt1602613', 4, 'Solo Dios perdona', 'AR', None, 'imdbDisplay', None, 0.0),
#  ('tt1602613', 5, 'Dievs Piedos', 'LV', None, 'alternative', None, 0.0),
#  ('tt1602613', 6, 'Onli gat bogibeuseu', 'KR', None, 'imdbDisplay', None, 0.0),
#  ('tt1602613', 7, 'Zui wu ke she', 'TW', None, 'imdbDisplay', None, 0.0),
#  ('tt1602613', 8, 'Only God Forgives', 'FR', None, 'imdbDisplay', None, 0.0),
#  ('tt1602613', 9, 'Az irgalmatlan', 'HU', None, 'alternative', None, 0.0),
#  ('tt1603463', 1, "Yuriko's Aroma", 'XWW', 'en', 'imdbDisplay', None, 0.0),
#  ('tt1603463', 2, 'Yuriko no aroma', 'JP', None, None, None, 0.0),
#  ('tt1603463', 3, 'Yuriko no aroma', None, None, 'original', None, 1.0),
#  ('tt1604171', 10, 'Абитуриентски бал', 'BG', 'bg', None, None, 0.0),
#  ('tt1604171',
#   11,
#   'Prom - Die Nacht deines Lebens',
#   'DE',
#   None,
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt1604171', 12, 'Prom - A végzős buli', 'HU', None, None, None, 0.0),
#  ('tt1604171', 13, 'Horos teleiofoiton', 'GR', None, 'dvd', None, 0.0),
#  ('tt1604171', 14, 'Prom', None, None, 'original', None, 1.0),
#  ('tt1604171',
#   15,
#   'Prom - A Primeira Noite do Resto da Tua Vida',
#   'PT',
#   None,
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt1604171',
#   16,
#   'A Melhor Festa do Ano',
#   'BR',
#   None,
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt1604171', 17, 'Maturanc', 'SI', None, 'imdbDisplay', None, 0.0),
#  ('tt1604171', 18, 'Mezuniyet Balosu', 'TR', 'tr', 'dvd', None, 0.0),
#  ('tt1604171', 19, 'Выпускной', 'RU', None, None, None, 0.0),
#  ('tt1604171', 1, 'Fin de curso', 'ES', None, 'imdbDisplay', None, 0.0),
#  ('tt1604171', 2, 'Prom', 'US', None, None, None, 0.0),
#  ('tt1604171', 3, 'Fin de curso', 'AR', None, 'imdbDisplay', None, 0.0),
#  ('tt1604171', 4, 'Bal maturalny', 'PL', None, 'imdbDisplay', None, 0.0),
#  ('tt1604171', 5, 'Le grand soir', 'FR', None, None, 'cable TV title', 0.0),
#  ('tt1604171',
#   6,
#   'Prom - Ballo di fine anno',
#   'IT',
#   None,
#   'imdbDisplay',
#   None,
#   0.0),
#  ('tt1604171', 7, 'Maturalna', 'HR', None, 'imdbDisplay', None, 0.0),
#  ('tt1604171', 8, 'Horos apofoiton', 'GR', None, 'imdbDisplay', None, 0.0),
#  ('tt1604171', 9, 'Balul de absolvire', 'RO', None, 'imdbDisplay', None, 0.0),
#  ('tt1604554',
#   1,
#   'Yakuza Hunters 2: The Revenge Duel in Hell',
#   'GB',
#   None,
#   'dvd',
#   None,
#   0.0),
#  ('tt1604554',
#   2,
#   'Yakuza-Busting Girls: Duel in Hell',
#   'XWW',
#   'en',
#   'imdbDisplay',
#   None,
#   0.0),
#  ...]

# %% [markdown]
# ## Convert SQL tables to Pandas Dataframes

# %%
# I'm choosing to convert all my tables to Dataframes because I feel it will be easier to work with
tmdb_movies_df = pd.read_sql('''SELECT *
                                FROM tmdb_movies''', conn)
tmdb_movies_df.head()
# Out:
#    index            genre_ids     id original_language  \
# 0      0      [12, 14, 10751]  12444                en
# 1      1  [14, 12, 16, 10751]  10191                en
# 2      2        [12, 28, 878]  10138                en
# 3      3      [16, 35, 10751]    862                en
# 4      4        [28, 878, 12]  27205                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                      How to Train Your Dragon      28.734   2010-03-26
# 2                                    Iron Man 2      28.515   2010-05-07
# 3                                     Toy Story      28.005   1995-11-22
# 4                                     Inception      27.920   2010-07-16
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                      How to Train Your Dragon           7.7        7610
# 2                                    Iron Man 2           6.8       12368
# 3                                     Toy Story           7.9       10174
# 4                                     Inception           8.3       22186

# %%
budgets_df = pd.read_sql('''SELECT *
                                FROM tn_movie_budgets''', conn)
budgets_df.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747

# %%
# Irrelevant
name_basics_df = pd.read_sql('''SELECT *
                                FROM imdb_name_basics''', conn)
name_basics_df.head()
# Out:
#       nconst       primary_name  birth_year  death_year  \
# 0  nm0061671  Mary Ellen Bauder         NaN         NaN
# 1  nm0061865       Joseph Bauer         NaN         NaN
# 2  nm0062070         Bruce Baum         NaN         NaN
# 3  nm0062195       Axel Baumann         NaN         NaN
# 4  nm0062798        Pete Baxter         NaN         NaN
#
#                                  primary_profession  \
# 0         miscellaneous,production_manager,producer
# 1        composer,music_department,sound_department
# 2                        miscellaneous,actor,writer
# 3  camera_department,cinematographer,art_department
# 4  production_designer,art_department,set_decorator
#
#                           known_for_titles
# 0  tt0837562,tt2398241,tt0844471,tt0118553
# 1  tt0896534,tt6791238,tt0287072,tt1682940
# 2  tt1470654,tt0363631,tt0104030,tt0102898
# 3  tt0114371,tt2004304,tt1618448,tt1224387
# 4  tt0452644,tt0452692,tt3458030,tt2178256

# %%
# Irrelevant
title_akas_df = pd.read_sql('''SELECT *
                                FROM title_akas''', conn) 
title_akas_df.head()
# Out:
#     title_id  ordering                                    title region  \
# 0  tt0369610        10                            Джурасик свят     BG
# 1  tt0369610        11                        Jurashikku warudo     JP
# 2  tt0369610        12  Jurassic World: O Mundo dos Dinossauros     BR
# 3  tt0369610        13                  O Mundo dos Dinossauros     BR
# 4  tt0369610        14                           Jurassic World     FR
#
#   language        types   attributes  is_original_title
# 0       bg         None         None                0.0
# 1     None  imdbDisplay         None                0.0
# 2     None  imdbDisplay         None                0.0
# 3     None         None  short title                0.0
# 4     None  imdbDisplay         None                0.0

# %%
movie_gross_df = pd.read_sql('''SELECT *
                                FROM bom_movie_gross''', conn)
movie_gross_df.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
title_basics_df = pd.read_sql('''SELECT *
                                FROM imdb_title_basics''', conn)
title_basics_df.head()
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 3        2018              NaN          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy

# %%
# Irrelevant 
title_ratings_df = pd.read_sql('''SELECT *
                                FROM title_ratings''', conn)
print(title_ratings_df.head())
title_ratings_df.info()
# Out:
#        tconst  averagerating  numvotes
# 0  tt10356526            8.3        31
# 1  tt10384606            8.9       559
# 2   tt1042974            6.4        20
# 3   tt1043726            4.2     50352
# 4   tt1060240            6.5        21
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73856 entries, 0 to 73855
# Data columns (total 3 columns):
# tconst           73856 non-null object
# averagerating    73856 non-null float64
# numvotes         73856 non-null int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.7+ MB

# %%
rt_reviews_df = pd.read_sql('''SELECT *
                                FROM rt_reviews''', conn)
rt_reviews_df.head()
# Out:
#    id                                             review rating   fresh  \
# 0   3  A distinctly gallows take on contemporary fina...    3/5   fresh
# 1   3  It's an allegory in search of a meaning that n...   None  rotten
# 2   3  ... life lived in a bubble in financial dealin...   None   fresh
# 3   3  Continuing along a line introduced in last yea...   None   fresh
# 4   3             ... a perverse twist on neorealism...    None   fresh
#
#            critic  top_critic         publisher               date
# 0      PJ Nabarro           0   Patrick Nabarro  November 10, 2018
# 1  Annalee Newitz           0           io9.com       May 23, 2018
# 2    Sean Axmaker           0  Stream on Demand    January 4, 2018
# 3   Daniel Kasman           0              MUBI  November 16, 2017
# 4            None           0      Cinema Scope   October 12, 2017

# %%
rt_movie_info_df = pd.read_sql('''SELECT *
                                FROM rt_movie_info''', conn)
rt_movie_info_df.head()
# Out:
#    id                                           synopsis rating  \
# 0   1  This gritty, fast-paced, and innovative police...      R
# 1   3  New York City, not-too-distant-future: Eric Pa...      R
# 2   5  Illeana Douglas delivers a superb performance ...      R
# 3   6  Michael Douglas runs afoul of a treacherous su...      R
# 4   7                                               None     NR
#
#                                  genre          director  \
# 0  Action and Adventure|Classics|Drama  William Friedkin
# 1    Drama|Science Fiction and Fantasy  David Cronenberg
# 2    Drama|Musical and Performing Arts    Allison Anders
# 3           Drama|Mystery and Suspense    Barry Levinson
# 4                        Drama|Romance    Rodney Bennett
#
#                             writer  theater_date      dvd_date currency  \
# 0                   Ernest Tidyman   Oct 9, 1971  Sep 25, 2001     None
# 1     David Cronenberg|Don DeLillo  Aug 17, 2012   Jan 1, 2013        $
# 2                   Allison Anders  Sep 13, 1996  Apr 18, 2000     None
# 3  Paul Attanasio|Michael Crichton   Dec 9, 1994  Aug 27, 1997     None
# 4                     Giles Cooper          None          None     None
#
#   box_office      runtime             studio
# 0       None  104 minutes               None
# 1    600,000  108 minutes  Entertainment One
# 2       None  116 minutes               None
# 3       None  128 minutes               None
# 4       None  200 minutes               None

# %% [markdown]
# ## Data Cleaning
# In the next couple of lines I will be:
# - Checking each DataFrame for null values
# - Deciding what the next course of action for the null values will be ie. deleting/filling in null values
# - Reformating dtypes if needed

# %% [markdown]
# ### Cleaning - tmdb_movies

# %%
# View Dataframe
tmdb_movies_df.head()
# Out:
#    index            genre_ids     id original_language  \
# 0      0      [12, 14, 10751]  12444                en
# 1      1  [14, 12, 16, 10751]  10191                en
# 2      2        [12, 28, 878]  10138                en
# 3      3      [16, 35, 10751]    862                en
# 4      4        [28, 878, 12]  27205                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                      How to Train Your Dragon      28.734   2010-03-26
# 2                                    Iron Man 2      28.515   2010-05-07
# 3                                     Toy Story      28.005   1995-11-22
# 4                                     Inception      27.920   2010-07-16
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                      How to Train Your Dragon           7.7        7610
# 2                                    Iron Man 2           6.8       12368
# 3                                     Toy Story           7.9       10174
# 4                                     Inception           8.3       22186

# %%
# Set 'Index' as the datasets index
tmdb_movies_df.set_index('index', inplace=True)
tmdb_movies_df.head()
# Out:
#                  genre_ids     id original_language  \
# index
# 0          [12, 14, 10751]  12444                en
# 1      [14, 12, 16, 10751]  10191                en
# 2            [12, 28, 878]  10138                en
# 3          [16, 35, 10751]    862                en
# 4            [28, 878, 12]  27205                en
#
#                                      original_title  popularity release_date  \
# index
# 0      Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                          How to Train Your Dragon      28.734   2010-03-26
# 2                                        Iron Man 2      28.515   2010-05-07
# 3                                         Toy Story      28.005   1995-11-22
# 4                                         Inception      27.920   2010-07-16
#
#                                               title  vote_average  vote_count
# index
# 0      Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                          How to Train Your Dragon           7.7        7610
# 2                                        Iron Man 2           6.8       12368
# 3                                         Toy Story           7.9       10174
# 4                                         Inception           8.3       22186

# %%
# Check df shape to see how many rows and columns we have
print(tmdb_movies_df.shape)

# View info for each column
tmdb_movies_df.info()
# Out:
# (26517, 9)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26517 entries, 0 to 26516
# Data columns (total 9 columns):
# genre_ids            26517 non-null object
# id                   26517 non-null int64
# original_language    26517 non-null object
# original_title       26517 non-null object
# popularity           26517 non-null float64
# release_date         26517 non-null object
# title                26517 non-null object
# vote_average         26517 non-null float64
# vote_count           26517 non-null int64
# dtypes: float64(2), int64(2), object(5)
# memory usage: 2.0+ MB

# %%
# Check for null values if any
print(tmdb_movies_df.isnull().sum())
# Out:
# genre_ids            0
# id                   0
# original_language    0
# original_title       0
# popularity           0
# release_date         0
# title                0
# vote_average         0
# vote_count           0
# dtype: int64

# %%
# It appears we don't have any null value -not any we can see right now at least-
# We'll explore the dataset more by checking out the Unique values
print('Number of Unique values:\n', tmdb_movies_df.nunique())
# Out:
# Number of Unique values:
#  genre_ids             2477
# id                   25497
# original_language       76
# original_title       24835
# popularity            7425
# release_date          3433
# title                24688
# vote_average            91
# vote_count            1693
# dtype: int64

# %%
# Going off the original_title and title columns its safe to assume there are some duplicate
tmdb_movies_df[tmdb_movies_df.duplicated(keep=False)].sort_values(by='title')
# Out:
#                 genre_ids      id original_language  \
# index
# 9191                 [99]   95383                en
# 6315                 [99]   95383                en
# 20070     [99, 36, 10770]  430364                en
# 26340     [99, 36, 10770]  430364                en
# 18016         [18, 10749]  416691                en
# ...                   ...     ...               ...
# 21273                [18]  326382                es
# 15061         [10751, 16]   94196                fr
# 5888          [10751, 16]   94196                fr
# 25188  [10752, 10751, 36]  472553                en
# 21676  [10752, 10751, 36]  472553                en
#
#                                        original_title  popularity  \
# index
# 9191                                       $ellebrity       1.420
# 6315                                       $ellebrity       1.420
# 20070  '85: The Greatest Team in Pro Football History       0.600
# 26340  '85: The Greatest Team in Pro Football History       0.600
# 18016                                         1 Night       5.409
# ...                                               ...         ...
# 21273                                            Zama       5.671
# 15061                                          Zarafa       2.705
# 5888                                           Zarafa       2.705
# 25188                                             Zoo       2.550
# 21676                                             Zoo       2.550
#
#       release_date                                           title  \
# index
# 9191    2013-01-11                                      $ellebrity
# 6315    2013-01-11                                      $ellebrity
# 20070   2018-01-29  '85: The Greatest Team in Pro Football History
# 26340   2018-01-29  '85: The Greatest Team in Pro Football History
# 18016   2017-02-10                                         1 Night
# ...            ...                                             ...
# 21273   2017-09-30                                            Zama
# 15061   2012-11-11                                          Zarafa
# 5888    2012-11-11                                          Zarafa
# 25188   2018-06-08                                             Zoo
# 21676   2018-06-08                                             Zoo
#
#        vote_average  vote_count
# index
# 9191            5.6          12
# 6315            5.6          12
# 20070           7.5           2
# 26340           7.5           2
# 18016           6.4         107
# ...             ...         ...
# 21273           6.9          50
# 15061           6.8          39
# 5888            6.8          39
# 25188           6.6          17
# 21676           6.6          17
#
# [2016 rows x 9 columns]

# %%
# We'll delete the duplicates as part of our data cleaning process
tmdb_movies_df.drop_duplicates(subset=['title'], inplace=True)

# %%
# Check to make sure changes were made to the dataset
tmdb_movies_df[tmdb_movies_df.duplicated(keep=False)].sort_values(by='title')
# Out:
# Empty DataFrame
# Columns: [genre_ids, id, original_language, original_title, popularity, release_date, title, vote_average, vote_count]
# Index: []

# %%
# Going back to the columns datatype we can see that release_date is stored as an object
print(tmdb_movies_df.dtypes)

# That can be fixed by changing it to a datetime dtype
# We can clearly see the before and after below
tmdb_movies_df['release_date'] = pd.to_datetime(tmdb_movies_df['release_date'])
tmdb_movies_df.info()
# Out:
# genre_ids             object
# id                     int64
# original_language     object
# original_title        object
# popularity           float64
# release_date          object
# title                 object
# vote_average         float64
# vote_count             int64
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24688 entries, 0 to 26516
# Data columns (total 9 columns):
# genre_ids            24688 non-null object
# id                   24688 non-null int64
# original_language    24688 non-null object
# original_title       24688 non-null object
# popularity           24688 non-null float64
# release_date         24688 non-null datetime64[ns]
# title                24688 non-null object
# vote_average         24688 non-null float64
# vote_count           24688 non-null int64
# dtypes: datetime64[ns](1), float64(2), int64(2), object(4)
# memory usage: 1.9+ MB

# %% [markdown]
# ### Cleaning - budgets_df

# %%
# View dataset
budgets_df.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747

# %%
# Check for null values\
budgets_df.isnull().sum()
# Out:
# id                   0
# release_date         0
# movie                0
# production_budget    0
# domestic_gross       0
# worldwide_gross      0
# dtype: int64

# %%
# Get blueprints of dataset
budgets_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
# id                   5782 non-null int64
# release_date         5782 non-null object
# movie                5782 non-null object
# production_budget    5782 non-null object
# domestic_gross       5782 non-null object
# worldwide_gross      5782 non-null object
# dtypes: int64(1), object(5)
# memory usage: 271.2+ KB

# %%
# Set 'id' as index
budgets_df.set_index('id', inplace=True)

# %%
# Check for duplicates
budgets_df[budgets_df.duplicated(keep=False)].sort_values(by='movie')
# Out:
# Empty DataFrame
# Columns: [release_date, movie, production_budget, domestic_gross, worldwide_gross]
# Index: []

# %%
# Looking at the datatypes the last 3 columns are stored as an object datatype 
# We'll be converting the last 3 columns to Integer datatypes
budgets_df['production_budget'] = budgets_df['production_budget'].str.replace('$','').str.replace(',','').astype('int')

# %%
budgets_df['domestic_gross'] = budgets_df['domestic_gross'].str.replace('$','').str.replace(',','').astype('int')

# %%
budgets_df['worldwide_gross'] = budgets_df['worldwide_gross'].str.replace('$','').str.replace(',','').astype('int')

# %%
budgets_df.head()
# Out:
#     release_date                                        movie  \
# id
# 1   Dec 18, 2009                                       Avatar
# 2   May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 3    Jun 7, 2019                                 Dark Phoenix
# 4    May 1, 2015                      Avengers: Age of Ultron
# 5   Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#     production_budget  domestic_gross  worldwide_gross
# id
# 1           425000000       760507625       2776345279
# 2           410600000       241063875       1045663875
# 3           350000000        42762350        149762350
# 4           330600000       459005868       1403013963
# 5           317000000       620181382       1316721747

# %%
budgets_df.dtypes
# Out:
# release_date         object
# movie                object
# production_budget     int64
# domestic_gross        int64
# worldwide_gross       int64
# dtype: object

# %% [markdown]
# ### Cleaning - movie_gross_df

# %%
# View data
movie_gross_df.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
# Check dtype
movie_gross_df.dtypes
# Out:
# title              object
# studio             object
# domestic_gross    float64
# foreign_gross      object
# year                int64
# dtype: object

# %%
# Check for null values
movie_gross_df.isna().sum()
# Out:
# title                0
# studio               5
# domestic_gross      28
# foreign_gross     1350
# year                 0
# dtype: int64

# %%
movie_gross_df.foreign_gross.dropna()
# Out:
# 0       652000000
# 1       691300000
# 2       664300000
# 3       535700000
# 4       513900000
#           ...
# 3275      1500000
# 3286       229000
# 3309       256000
# 3342         5200
# 3353        30000
# Name: foreign_gross, Length: 2037, dtype: object

# %%
movie_gross_df = movie_gross_df.dropna()

# %%
movie_gross_df.isna().sum()
# Out:
# title             0
# studio            0
# domestic_gross    0
# foreign_gross     0
# year              0
# dtype: int64
